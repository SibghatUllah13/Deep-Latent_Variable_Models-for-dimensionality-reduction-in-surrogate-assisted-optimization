# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'errorbar.capsize': 10})
import seaborn as sns

from matplotlib import rcParams
import numpy as np
import pandas as pd
import sys
from scipy.stats import mannwhitneyu
from collections import OrderedDict
rcParams["legend.numpoints"] = 1
import matplotlib.pyplot as plt
from matplotlib.transforms import offset_copy

linestyles = OrderedDict(
    [('solid',               (0, ())),
     ('loosely dotted',      (0, (1, 10))),
     ('dotted',              (0, (1, 5))),
     ('densely dotted',      (0, (1, 1))),

     ('loosely dashed',      (0, (5, 10))),
     ('dashed',              (0, (5, 5))),
     ('densely dashed',      (0, (5, 1))),

     ('loosely dashdotted',  (0, (3, 10, 1, 10))),
     ('dashdotted',          (0, (3, 5, 1, 5))),
     ('densely dashdotted',  (0, (3, 1, 1, 1))),

     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))])

Style = []
for i, (name, linestyle) in enumerate(linestyles.items()):
    Style.append(linestyle)
X = ['F2','F3','F7','F9','F10','F13','F15','F16','F20','F24']

# %% [markdown]
# ##  50 D

# %%
orig_path = "Surrogate Modeling\\Original\\Modeling Accuracy\\50 D\\Results\\"
orig_f2 = pd.read_csv(orig_path+'F2_Accuracy.csv', index_col=0)
orig_f3 = pd.read_csv(orig_path+'F3_Accuracy.csv', index_col=0)
orig_f7 = pd.read_csv(orig_path+'F7_Accuracy.csv', index_col=0)
orig_f9 = pd.read_csv(orig_path+'F9_Accuracy.csv', index_col=0)
orig_f10 = pd.read_csv(orig_path+'F10_Accuracy.csv', index_col=0)
orig_f13 = pd.read_csv(orig_path+'F13_Accuracy.csv', index_col=0)
orig_f15 = pd.read_csv(orig_path+'F15_Accuracy.csv', index_col=0)
orig_f16 = pd.read_csv(orig_path+'F16_Accuracy.csv', index_col=0)
orig_f20 = pd.read_csv(orig_path+'F20_Accuracy.csv', index_col=0)
orig_f24 = pd.read_csv(orig_path+'F24_Accuracy.csv', index_col=0)

lat_50_path = "Surrogate Modeling\\Latent\\Modeling Accuracy\\50 %\\50 D\\Results\\"
lat_50_f2 = pd.read_csv(lat_50_path+'F2_Accuracy.csv', index_col=0)
lat_50_f3 = pd.read_csv(lat_50_path+'F3_Accuracy.csv', index_col=0)
lat_50_f7 = pd.read_csv(lat_50_path+'F7_Accuracy.csv', index_col=0)
lat_50_f9 = pd.read_csv(lat_50_path+'F9_Accuracy.csv', index_col=0)
lat_50_f10 = pd.read_csv(lat_50_path+'F10_Accuracy.csv', index_col=0)
lat_50_f13 = pd.read_csv(lat_50_path+'F13_Accuracy.csv', index_col=0)
lat_50_f15 = pd.read_csv(lat_50_path+'F15_Accuracy.csv', index_col=0)
lat_50_f16 = pd.read_csv(lat_50_path+'F16_Accuracy.csv', index_col=0)
lat_50_f20 = pd.read_csv(lat_50_path+'F20_Accuracy.csv', index_col=0)
lat_50_f24 = pd.read_csv(lat_50_path+'F24_Accuracy.csv', index_col=0)



lat_70_path = "Surrogate Modeling\\Latent\\Modeling Accuracy\\70 %\\50 D\\Results\\"
lat_70_f2 = pd.read_csv(lat_70_path+'F2_Accuracy.csv', index_col=0)
lat_70_f3 = pd.read_csv(lat_70_path+'F3_Accuracy.csv', index_col=0)
lat_70_f7 = pd.read_csv(lat_70_path+'F7_Accuracy.csv', index_col=0)
lat_70_f9 = pd.read_csv(lat_70_path+'F9_Accuracy.csv', index_col=0)
lat_70_f10 = pd.read_csv(lat_70_path+'F10_Accuracy.csv', index_col=0)
lat_70_f13 = pd.read_csv(lat_70_path+'F13_Accuracy.csv', index_col=0)
lat_70_f15 = pd.read_csv(lat_70_path+'F15_Accuracy.csv', index_col=0)
lat_70_f16 = pd.read_csv(lat_70_path+'F16_Accuracy.csv', index_col=0)
lat_70_f20 = pd.read_csv(lat_70_path+'F20_Accuracy.csv', index_col=0)
lat_70_f24 = pd.read_csv(lat_70_path+'F24_Accuracy.csv', index_col=0)


lat_90_path = "Surrogate Modeling\\Latent\\Modeling Accuracy\\90 %\\50 D\\Results\\"
lat_90_f2 = pd.read_csv(lat_90_path+'F2_Accuracy.csv', index_col=0)
lat_90_f3 = pd.read_csv(lat_90_path+'F3_Accuracy.csv', index_col=0)
lat_90_f7 = pd.read_csv(lat_90_path+'F7_Accuracy.csv', index_col=0)
lat_90_f9 = pd.read_csv(lat_90_path+'F9_Accuracy.csv', index_col=0)
lat_90_f10 = pd.read_csv(lat_90_path+'F10_Accuracy.csv', index_col=0)
lat_90_f13 = pd.read_csv(lat_90_path+'F13_Accuracy.csv', index_col=0)
lat_90_f15 = pd.read_csv(lat_90_path+'F15_Accuracy.csv', index_col=0)
lat_90_f16 = pd.read_csv(lat_90_path+'F16_Accuracy.csv', index_col=0)
lat_90_f20 = pd.read_csv(lat_90_path+'F20_Accuracy.csv', index_col=0)
lat_90_f24 = pd.read_csv(lat_90_path+'F24_Accuracy.csv', index_col=0)

# %%
error_orig_f2 = pd.DataFrame(data= [(abs(orig_f2['True']-orig_f2['ELN'])/abs(orig_f2['True'])) * 100 , 
                   (abs(orig_f2['True']-orig_f2['KNN'])/abs(orig_f2['True'])) * 100, 
                   (abs(orig_f2['True']-orig_f2['Kri'])/abs(orig_f2['True'])) * 100,
                    (abs(orig_f2['True']-orig_f2['SVR'])/abs(orig_f2['True'])) * 100]).T
error_orig_f2.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']


error_orig_f3 = pd.DataFrame(data= [(abs(orig_f3['True']-orig_f3['ELN'])/abs(orig_f3['True'])) * 100 , 
                   (abs(orig_f3['True']-orig_f3['KNN'])/abs(orig_f3['True'])) * 100, 
                   (abs(orig_f3['True']-orig_f3['Kri'])/abs(orig_f3['True'])) * 100,
                    (abs(orig_f3['True']-orig_f3['SVR'])/abs(orig_f3['True'])) * 100]).T
error_orig_f3.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f7 = pd.DataFrame(data= [(abs(orig_f7['True']-orig_f7['ELN'])/abs(orig_f7['True'])) * 100 , 
                   (abs(orig_f7['True']-orig_f7['KNN'])/abs(orig_f7['True'])) * 100, 
                   (abs(orig_f7['True']-orig_f7['Kri'])/abs(orig_f7['True'])) * 100,
                    (abs(orig_f7['True']-orig_f7['SVR'])/abs(orig_f7['True'])) * 100]).T
error_orig_f7.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f9 = pd.DataFrame(data= [(abs(orig_f9['True']-orig_f9['ELN'])/abs(orig_f9['True'])) * 100 , 
                   (abs(orig_f9['True']-orig_f9['KNN'])/abs(orig_f9['True'])) * 100, 
                   (abs(orig_f9['True']-orig_f9['Kri'])/abs(orig_f9['True'])) * 100,
                    (abs(orig_f9['True']-orig_f9['SVR'])/abs(orig_f9['True'])) * 100]).T
error_orig_f9.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f10 = pd.DataFrame(data= [(abs(orig_f10['True']-orig_f10['ELN'])/abs(orig_f10['True'])) * 100 , 
                   (abs(orig_f10['True']-orig_f10['KNN'])/abs(orig_f10['True'])) * 100, 
                   (abs(orig_f10['True']-orig_f10['Kri'])/abs(orig_f10['True'])) * 100,
                    (abs(orig_f10['True']-orig_f10['SVR'])/abs(orig_f10['True'])) * 100]).T
error_orig_f10.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f13 = pd.DataFrame(data= [(abs(orig_f13['True']-orig_f13['ELN'])/abs(orig_f13['True'])) * 100 , 
                   (abs(orig_f13['True']-orig_f13['KNN'])/abs(orig_f13['True'])) * 100, 
                   (abs(orig_f13['True']-orig_f13['Kri'])/abs(orig_f13['True'])) * 100,
                    (abs(orig_f13['True']-orig_f13['SVR'])/abs(orig_f13['True'])) * 100]).T
error_orig_f13.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f15 = pd.DataFrame(data= [(abs(orig_f15['True']-orig_f15['ELN'])/abs(orig_f15['True'])) * 100 , 
                   (abs(orig_f15['True']-orig_f15['KNN'])/abs(orig_f15['True'])) * 100, 
                   (abs(orig_f15['True']-orig_f15['Kri'])/abs(orig_f15['True'])) * 100,
                    (abs(orig_f15['True']-orig_f15['SVR'])/abs(orig_f15['True'])) * 100]).T
error_orig_f15.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f16 = pd.DataFrame(data= [(abs(orig_f16['True']-orig_f16['ELN'])/abs(orig_f16['True'])) * 100 , 
                   (abs(orig_f16['True']-orig_f16['KNN'])/abs(orig_f16['True'])) * 100, 
                   (abs(orig_f16['True']-orig_f16['Kri'])/abs(orig_f16['True'])) * 100,
                    (abs(orig_f16['True']-orig_f16['SVR'])/abs(orig_f16['True'])) * 100]).T
error_orig_f16.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f20 = pd.DataFrame(data= [(abs(orig_f20['True']-orig_f20['ELN'])/abs(orig_f20['True'])) * 100 , 
                   (abs(orig_f20['True']-orig_f20['KNN'])/abs(orig_f20['True'])) * 100, 
                   (abs(orig_f20['True']-orig_f20['Kri'])/abs(orig_f20['True'])) * 100,
                    (abs(orig_f20['True']-orig_f20['SVR'])/abs(orig_f20['True'])) * 100]).T
error_orig_f20.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f24 = pd.DataFrame(data= [(abs(orig_f24['True']-orig_f24['ELN'])/abs(orig_f20['True'])) * 100 , 
                   (abs(orig_f24['True']-orig_f24['KNN'])/abs(orig_f24['True'])) * 100, 
                   (abs(orig_f24['True']-orig_f24['Kri'])/abs(orig_f24['True'])) * 100,
                    (abs(orig_f24['True']-orig_f24['SVR'])/abs(orig_f24['True'])) * 100]).T
error_orig_f24.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_50_f2 = pd.DataFrame(data= [(abs(lat_50_f2['True']-lat_50_f2['ELN'])/abs(lat_50_f2['True'])) * 100 , 
                   (abs(lat_50_f2['True']-lat_50_f2['KNN'])/abs(lat_50_f2['True'])) * 100, 
                   (abs(lat_50_f2['True']-lat_50_f2['Kri'])/abs(lat_50_f2['True'])) * 100,
                    (abs(lat_50_f2['True']-lat_50_f2['SVR'])/abs(lat_50_f2['True'])) * 100]).T
error_50_f2.columns = ['ELN','KNN','Kri','SVR']

error_50_f3 = pd.DataFrame(data= [(abs(lat_50_f3['True']-lat_50_f3['ELN'])/abs(lat_50_f3['True'])) * 100 , 
                   (abs(lat_50_f3['True']-lat_50_f3['KNN'])/abs(lat_50_f3['True'])) * 100, 
                   (abs(lat_50_f3['True']-lat_50_f3['Kri'])/abs(lat_50_f3['True'])) * 100,
                    (abs(lat_50_f3['True']-lat_50_f3['SVR'])/abs(lat_50_f3['True'])) * 100]).T
error_50_f3.columns = ['ELN','KNN','Kri','SVR']

error_50_f7 = pd.DataFrame(data= [(abs(lat_50_f7['True']-lat_50_f7['ELN'])/abs(lat_50_f7['True'])) * 100 , 
                   (abs(lat_50_f7['True']-lat_50_f7['KNN'])/abs(lat_50_f7['True'])) * 100, 
                   (abs(lat_50_f7['True']-lat_50_f7['Kri'])/abs(lat_50_f7['True'])) * 100,
                    (abs(lat_50_f7['True']-lat_50_f7['SVR'])/abs(lat_50_f7['True'])) * 100]).T
error_50_f7.columns = ['ELN','KNN','Kri','SVR']

error_50_f9 = pd.DataFrame(data= [(abs(lat_50_f9['True']-lat_50_f9['ELN'])/abs(lat_50_f9['True'])) * 100 , 
                   (abs(lat_50_f9['True']-lat_50_f9['KNN'])/abs(lat_50_f9['True'])) * 100, 
                   (abs(lat_50_f9['True']-lat_50_f9['Kri'])/abs(lat_50_f9['True'])) * 100,
                    (abs(lat_50_f9['True']-lat_50_f9['SVR'])/abs(lat_50_f9['True'])) * 100]).T
error_50_f9.columns = ['ELN','KNN','Kri','SVR']

error_50_f10 = pd.DataFrame(data= [(abs(lat_50_f10['True']-lat_50_f10['ELN'])/abs(lat_50_f10['True'])) * 100 , 
                   (abs(lat_50_f10['True']-lat_50_f10['KNN'])/abs(lat_50_f10['True'])) * 100, 
                   (abs(lat_50_f10['True']-lat_50_f10['Kri'])/abs(lat_50_f10['True'])) * 100,
                    (abs(lat_50_f10['True']-lat_50_f10['SVR'])/abs(lat_50_f10['True'])) * 100]).T
error_50_f10.columns = ['ELN','KNN','Kri','SVR']

error_50_f13 = pd.DataFrame(data= [(abs(lat_50_f13['True']-lat_50_f13['ELN'])/abs(lat_50_f13['True'])) * 100 , 
                   (abs(lat_50_f13['True']-lat_50_f13['KNN'])/abs(lat_50_f13['True'])) * 100, 
                   (abs(lat_50_f13['True']-lat_50_f13['Kri'])/abs(lat_50_f13['True'])) * 100,
                    (abs(lat_50_f13['True']-lat_50_f13['SVR'])/abs(lat_50_f13['True'])) * 100]).T
error_50_f13.columns = ['ELN','KNN','Kri','SVR']

error_50_f15 = pd.DataFrame(data= [(abs(lat_50_f15['True']-lat_50_f15['ELN'])/abs(lat_50_f15['True'])) * 100 , 
                   (abs(lat_50_f15['True']-lat_50_f15['KNN'])/abs(lat_50_f15['True'])) * 100, 
                   (abs(lat_50_f15['True']-lat_50_f15['Kri'])/abs(lat_50_f15['True'])) * 100,
                    (abs(lat_50_f15['True']-lat_50_f15['SVR'])/abs(lat_50_f15['True'])) * 100]).T
error_50_f15.columns = ['ELN','KNN','Kri','SVR']

error_50_f16 = pd.DataFrame(data= [(abs(lat_50_f16['True']-lat_50_f16['ELN'])/abs(lat_50_f16['True'])) * 100 , 
                   (abs(lat_50_f16['True']-lat_50_f16['KNN'])/abs(lat_50_f16['True'])) * 100, 
                   (abs(lat_50_f16['True']-lat_50_f16['Kri'])/abs(lat_50_f16['True'])) * 100,
                    (abs(lat_50_f16['True']-lat_50_f16['SVR'])/abs(lat_50_f16['True'])) * 100]).T
error_50_f16.columns = ['ELN','KNN','Kri','SVR']

error_50_f20 = pd.DataFrame(data= [(abs(lat_50_f20['True']-lat_50_f20['ELN'])/abs(lat_50_f20['True'])) * 100 , 
                   (abs(lat_50_f20['True']-lat_50_f20['KNN'])/abs(lat_50_f20['True'])) * 100, 
                   (abs(lat_50_f20['True']-lat_50_f20['Kri'])/abs(lat_50_f20['True'])) * 100,
                    (abs(lat_50_f20['True']-lat_50_f20['SVR'])/abs(lat_50_f20['True'])) * 100]).T
error_50_f20.columns = ['ELN','KNN','Kri','SVR']

error_50_f24 = pd.DataFrame(data= [(abs(lat_50_f24['True']-lat_50_f24['ELN'])/abs(lat_50_f24['True'])) * 100 , 
                   (abs(lat_50_f24['True']-lat_50_f24['KNN'])/abs(lat_50_f24['True'])) * 100, 
                   (abs(lat_50_f24['True']-lat_50_f24['Kri'])/abs(lat_50_f24['True'])) * 100,
                    (abs(lat_50_f24['True']-lat_50_f24['SVR'])/abs(lat_50_f24['True'])) * 100]).T
error_50_f24.columns = ['ELN','KNN','Kri','SVR']


error_70_f2 = pd.DataFrame(data= [(abs(lat_70_f2['True']-lat_70_f2['ELN'])/abs(lat_70_f2['True'])) * 100 , 
                   (abs(lat_70_f2['True']-lat_70_f2['KNN'])/abs(lat_70_f2['True'])) * 100, 
                   (abs(lat_70_f2['True']-lat_70_f2['Kri'])/abs(lat_70_f2['True'])) * 100,
                    (abs(lat_70_f2['True']-lat_70_f2['SVR'])/abs(lat_70_f2['True'])) * 100]).T
error_70_f2.columns = ['ELN','KNN','Kri','SVR']

error_70_f3 = pd.DataFrame(data= [(abs(lat_70_f3['True']-lat_70_f3['ELN'])/abs(lat_70_f3['True'])) * 100 , 
                   (abs(lat_70_f3['True']-lat_70_f3['KNN'])/abs(lat_70_f3['True'])) * 100, 
                   (abs(lat_70_f3['True']-lat_70_f3['Kri'])/abs(lat_70_f3['True'])) * 100,
                    (abs(lat_70_f3['True']-lat_70_f3['SVR'])/abs(lat_70_f3['True'])) * 100]).T
error_70_f3.columns = ['ELN','KNN','Kri','SVR']

error_70_f7 = pd.DataFrame(data= [(abs(lat_70_f7['True']-lat_70_f7['ELN'])/abs(lat_70_f7['True'])) * 100 , 
                   (abs(lat_70_f7['True']-lat_70_f7['KNN'])/abs(lat_70_f7['True'])) * 100, 
                   (abs(lat_70_f7['True']-lat_70_f7['Kri'])/abs(lat_70_f7['True'])) * 100,
                    (abs(lat_70_f7['True']-lat_70_f7['SVR'])/abs(lat_70_f7['True'])) * 100]).T
error_70_f7.columns = ['ELN','KNN','Kri','SVR']

error_70_f9 = pd.DataFrame(data= [(abs(lat_70_f9['True']-lat_70_f9['ELN'])/abs(lat_70_f9['True'])) * 100 , 
                   (abs(lat_70_f9['True']-lat_70_f9['KNN'])/abs(lat_70_f9['True'])) * 100, 
                   (abs(lat_70_f9['True']-lat_70_f9['Kri'])/abs(lat_70_f9['True'])) * 100,
                    (abs(lat_70_f9['True']-lat_70_f9['SVR'])/abs(lat_70_f9['True'])) * 100]).T
error_70_f9.columns = ['ELN','KNN','Kri','SVR']

error_70_f10 = pd.DataFrame(data= [(abs(lat_70_f10['True']-lat_70_f10['ELN'])/abs(lat_70_f10['True'])) * 100 , 
                   (abs(lat_70_f10['True']-lat_70_f10['KNN'])/abs(lat_70_f10['True'])) * 100, 
                   (abs(lat_70_f10['True']-lat_70_f10['Kri'])/abs(lat_70_f10['True'])) * 100,
                    (abs(lat_70_f10['True']-lat_70_f10['SVR'])/abs(lat_70_f10['True'])) * 100]).T
error_70_f10.columns = ['ELN','KNN','Kri','SVR']

error_70_f13 = pd.DataFrame(data= [(abs(lat_70_f13['True']-lat_70_f13['ELN'])/abs(lat_70_f13['True'])) * 100 , 
                   (abs(lat_70_f13['True']-lat_70_f13['KNN'])/abs(lat_70_f13['True'])) * 100, 
                   (abs(lat_70_f13['True']-lat_70_f13['Kri'])/abs(lat_70_f13['True'])) * 100,
                    (abs(lat_70_f13['True']-lat_70_f13['SVR'])/abs(lat_70_f13['True'])) * 100]).T
error_70_f13.columns = ['ELN','KNN','Kri','SVR']

error_70_f15 = pd.DataFrame(data= [(abs(lat_70_f15['True']-lat_70_f15['ELN'])/abs(lat_70_f15['True'])) * 100 , 
                   (abs(lat_70_f15['True']-lat_70_f15['KNN'])/abs(lat_70_f15['True'])) * 100, 
                   (abs(lat_70_f15['True']-lat_70_f15['Kri'])/abs(lat_70_f15['True'])) * 100,
                    (abs(lat_70_f15['True']-lat_70_f15['SVR'])/abs(lat_70_f15['True'])) * 100]).T
error_70_f15.columns = ['ELN','KNN','Kri','SVR']

error_70_f16 = pd.DataFrame(data= [(abs(lat_70_f16['True']-lat_70_f16['ELN'])/abs(lat_70_f16['True'])) * 100 , 
                   (abs(lat_70_f16['True']-lat_70_f16['KNN'])/abs(lat_70_f16['True'])) * 100, 
                   (abs(lat_70_f16['True']-lat_70_f16['Kri'])/abs(lat_70_f16['True'])) * 100,
                    (abs(lat_70_f16['True']-lat_70_f16['SVR'])/abs(lat_70_f16['True'])) * 100]).T
error_70_f16.columns = ['ELN','KNN','Kri','SVR']

error_70_f20 = pd.DataFrame(data= [(abs(lat_70_f20['True']-lat_70_f20['ELN'])/abs(lat_70_f20['True'])) * 100 , 
                   (abs(lat_70_f20['True']-lat_70_f20['KNN'])/abs(lat_70_f20['True'])) * 100, 
                   (abs(lat_70_f20['True']-lat_70_f20['Kri'])/abs(lat_70_f20['True'])) * 100,
                    (abs(lat_70_f20['True']-lat_70_f20['SVR'])/abs(lat_70_f20['True'])) * 100]).T
error_70_f20.columns = ['ELN','KNN','Kri','SVR']

error_70_f24 = pd.DataFrame(data= [(abs(lat_70_f24['True']-lat_70_f24['ELN'])/abs(lat_70_f24['True'])) * 100 , 
                   (abs(lat_70_f24['True']-lat_70_f24['KNN'])/abs(lat_70_f24['True'])) * 100, 
                   (abs(lat_70_f24['True']-lat_70_f24['Kri'])/abs(lat_70_f24['True'])) * 100,
                    (abs(lat_70_f24['True']-lat_70_f24['SVR'])/abs(lat_70_f24['True'])) * 100]).T
error_70_f24.columns = ['ELN','KNN','Kri','SVR']



error_90_f2 = pd.DataFrame(data= [(abs(lat_90_f2['True']-lat_90_f2['ELN'])/abs(lat_90_f2['True'])) * 100 , 
                   (abs(lat_90_f2['True']-lat_90_f2['KNN'])/abs(lat_90_f2['True'])) * 100, 
                   (abs(lat_90_f2['True']-lat_90_f2['Kri'])/abs(lat_90_f2['True'])) * 100,
                    (abs(lat_90_f2['True']-lat_90_f2['SVR'])/abs(lat_90_f2['True'])) * 100]).T
error_90_f2.columns = ['ELN','KNN','Kri','SVR']

error_90_f3 = pd.DataFrame(data= [(abs(lat_90_f3['True']-lat_90_f3['ELN'])/abs(lat_90_f3['True'])) * 100 , 
                   (abs(lat_90_f3['True']-lat_90_f3['KNN'])/abs(lat_90_f3['True'])) * 100, 
                   (abs(lat_90_f3['True']-lat_90_f3['Kri'])/abs(lat_90_f3['True'])) * 100,
                    (abs(lat_90_f3['True']-lat_90_f3['SVR'])/abs(lat_90_f3['True'])) * 100]).T
error_90_f3.columns = ['ELN','KNN','Kri','SVR']

error_90_f7 = pd.DataFrame(data= [(abs(lat_90_f7['True']-lat_90_f7['ELN'])/abs(lat_90_f7['True'])) * 100 , 
                   (abs(lat_90_f7['True']-lat_90_f7['KNN'])/abs(lat_90_f7['True'])) * 100, 
                   (abs(lat_90_f7['True']-lat_90_f7['Kri'])/abs(lat_90_f7['True'])) * 100,
                    (abs(lat_90_f7['True']-lat_90_f7['SVR'])/abs(lat_90_f7['True'])) * 100]).T
error_90_f7.columns = ['ELN','KNN','Kri','SVR']

error_90_f9 = pd.DataFrame(data= [(abs(lat_90_f9['True']-lat_90_f9['ELN'])/abs(lat_90_f9['True'])) * 100 , 
                   (abs(lat_90_f9['True']-lat_90_f9['KNN'])/abs(lat_90_f9['True'])) * 100, 
                   (abs(lat_90_f9['True']-lat_90_f9['Kri'])/abs(lat_90_f9['True'])) * 100,
                    (abs(lat_90_f9['True']-lat_90_f9['SVR'])/abs(lat_90_f9['True'])) * 100]).T
error_90_f9.columns = ['ELN','KNN','Kri','SVR']

error_90_f10 = pd.DataFrame(data= [(abs(lat_90_f10['True']-lat_90_f10['ELN'])/abs(lat_90_f10['True'])) * 100 , 
                   (abs(lat_90_f10['True']-lat_90_f10['KNN'])/abs(lat_90_f10['True'])) * 100, 
                   (abs(lat_90_f10['True']-lat_90_f10['Kri'])/abs(lat_90_f10['True'])) * 100,
                    (abs(lat_90_f10['True']-lat_90_f10['SVR'])/abs(lat_90_f10['True'])) * 100]).T
error_90_f10.columns = ['ELN','KNN','Kri','SVR']

error_90_f13 = pd.DataFrame(data= [(abs(lat_90_f13['True']-lat_90_f13['ELN'])/abs(lat_90_f13['True'])) * 100 , 
                   (abs(lat_90_f13['True']-lat_90_f13['KNN'])/abs(lat_90_f13['True'])) * 100, 
                   (abs(lat_90_f13['True']-lat_90_f13['Kri'])/abs(lat_90_f13['True'])) * 100,
                    (abs(lat_90_f13['True']-lat_90_f13['SVR'])/abs(lat_90_f13['True'])) * 100]).T
error_90_f13.columns = ['ELN','KNN','Kri','SVR']

error_90_f15 = pd.DataFrame(data= [(abs(lat_90_f15['True']-lat_90_f15['ELN'])/abs(lat_90_f15['True'])) * 100 , 
                   (abs(lat_90_f15['True']-lat_90_f15['KNN'])/abs(lat_90_f15['True'])) * 100, 
                   (abs(lat_90_f15['True']-lat_90_f15['Kri'])/abs(lat_90_f15['True'])) * 100,
                    (abs(lat_90_f15['True']-lat_90_f15['SVR'])/abs(lat_90_f15['True'])) * 100]).T
error_90_f15.columns = ['ELN','KNN','Kri','SVR']

error_90_f16 = pd.DataFrame(data= [(abs(lat_90_f16['True']-lat_90_f16['ELN'])/abs(lat_90_f16['True'])) * 100 , 
                   (abs(lat_90_f16['True']-lat_90_f16['KNN'])/abs(lat_90_f16['True'])) * 100, 
                   (abs(lat_90_f16['True']-lat_90_f16['Kri'])/abs(lat_90_f16['True'])) * 100,
                    (abs(lat_90_f16['True']-lat_90_f16['SVR'])/abs(lat_90_f16['True'])) * 100]).T
error_90_f16.columns = ['ELN','KNN','Kri','SVR']

error_90_f20 = pd.DataFrame(data= [(abs(lat_90_f20['True']-lat_90_f20['ELN'])/abs(lat_90_f20['True'])) * 100 , 
                   (abs(lat_90_f20['True']-lat_90_f20['KNN'])/abs(lat_90_f20['True'])) * 100, 
                   (abs(lat_90_f20['True']-lat_90_f20['Kri'])/abs(lat_90_f20['True'])) * 100,
                    (abs(lat_90_f20['True']-lat_90_f20['SVR'])/abs(lat_90_f20['True'])) * 100]).T
error_90_f20.columns = ['ELN','KNN','Kri','SVR']

error_90_f24 = pd.DataFrame(data= [(abs(lat_90_f24['True']-lat_90_f24['ELN'])/abs(lat_90_f24['True'])) * 100 , 
                   (abs(lat_90_f24['True']-lat_90_f24['KNN'])/abs(lat_90_f24['True'])) * 100, 
                   (abs(lat_90_f24['True']-lat_90_f24['Kri'])/abs(lat_90_f24['True'])) * 100,
                    (abs(lat_90_f24['True']-lat_90_f24['SVR'])/abs(lat_90_f24['True'])) * 100]).T
error_90_f24.columns = ['ELN','KNN','Kri','SVR']

# %%
f2_poly_rmae  = [ error_orig_f2.mean()[0] , error_50_f2.mean()[0], error_70_f2.mean()[0], error_90_f2.mean()[0] ]
f2_knn_rmae  = [ error_orig_f2.mean()[1] , error_50_f2.mean()[1], error_70_f2.mean()[1], error_90_f2.mean()[1] ]
f2_kri_rmae  = [ error_orig_f2.mean()[2] , error_50_f2.mean()[2], error_70_f2.mean()[2], error_90_f2.mean()[2] ]
f2_svr_rmae  = [ error_orig_f2.mean()[3] , error_50_f2.mean()[3], error_70_f2.mean()[3], error_90_f2.mean()[3] ]

f3_poly_rmae  = [ error_orig_f3.mean()[0] , error_50_f3.mean()[0], error_70_f3.mean()[0], error_90_f3.mean()[0] ]
f3_knn_rmae  = [ error_orig_f3.mean()[1] , error_50_f3.mean()[1], error_70_f3.mean()[1], error_90_f3.mean()[1] ]
f3_kri_rmae  = [ error_orig_f3.mean()[2] , error_50_f3.mean()[2], error_70_f3.mean()[2], error_90_f3.mean()[2] ]
f3_svr_rmae  = [ error_orig_f3.mean()[3] , error_50_f3.mean()[3], error_70_f3.mean()[3], error_90_f3.mean()[3] ]

f7_poly_rmae  = [ error_orig_f7.mean()[0] , error_50_f7.mean()[0], error_70_f7.mean()[0], error_90_f7.mean()[0] ]
f7_knn_rmae  = [ error_orig_f7.mean()[1] , error_50_f7.mean()[1], error_70_f7.mean()[1], error_90_f7.mean()[1] ]
f7_kri_rmae  = [ error_orig_f7.mean()[2] , error_50_f7.mean()[2], error_70_f7.mean()[2], error_90_f7.mean()[2] ]
f7_svr_rmae  = [ error_orig_f7.mean()[3] , error_50_f7.mean()[3], error_70_f7.mean()[3], error_90_f7.mean()[3] ]

f9_poly_rmae  = [ error_orig_f9.mean()[0] , error_50_f9.mean()[0], error_70_f9.mean()[0], error_90_f9.mean()[0] ]
f9_knn_rmae  = [ error_orig_f9.mean()[1] , error_50_f9.mean()[1], error_70_f9.mean()[1], error_90_f9.mean()[1] ]
f9_kri_rmae  = [ error_orig_f9.mean()[2] , error_50_f9.mean()[2], error_70_f9.mean()[2], error_90_f9.mean()[2] ]
f9_svr_rmae  = [ error_orig_f9.mean()[3] , error_50_f9.mean()[3], error_70_f9.mean()[3], error_90_f9.mean()[3] ]

f10_poly_rmae  = [ error_orig_f10.mean()[0] , error_50_f10.mean()[0], error_70_f10.mean()[0], error_90_f10.mean()[0] ]
f10_knn_rmae  = [ error_orig_f10.mean()[1] , error_50_f10.mean()[1], error_70_f10.mean()[1], error_90_f10.mean()[1] ]
f10_kri_rmae  = [ error_orig_f10.mean()[2] , error_50_f10.mean()[2], error_70_f10.mean()[2], error_90_f10.mean()[2] ]
f10_svr_rmae  = [ error_orig_f10.mean()[3] , error_50_f10.mean()[3], error_70_f10.mean()[3], error_90_f10.mean()[3] ]

f13_poly_rmae  = [ error_orig_f13.mean()[0] , error_50_f13.mean()[0], error_70_f13.mean()[0], error_90_f13.mean()[0] ]
f13_knn_rmae  = [ error_orig_f13.mean()[1] , error_50_f13.mean()[1], error_70_f13.mean()[1], error_90_f13.mean()[1] ]
f13_kri_rmae  = [ error_orig_f13.mean()[2] , error_50_f13.mean()[2], error_70_f13.mean()[2], error_90_f13.mean()[2] ]
f13_svr_rmae  = [ error_orig_f13.mean()[3] , error_50_f13.mean()[3], error_70_f13.mean()[3], error_90_f13.mean()[3] ]

f15_poly_rmae  = [ error_orig_f15.mean()[0] , error_50_f15.mean()[0], error_70_f15.mean()[0], error_90_f15.mean()[0] ]
f15_knn_rmae  = [ error_orig_f15.mean()[1] , error_50_f15.mean()[1], error_70_f15.mean()[1], error_90_f15.mean()[1] ]
f15_kri_rmae  = [ error_orig_f15.mean()[2] , error_50_f15.mean()[2], error_70_f15.mean()[2], error_90_f15.mean()[2] ]
f15_svr_rmae  = [ error_orig_f15.mean()[3] , error_50_f15.mean()[3], error_70_f15.mean()[3], error_90_f15.mean()[3] ]

f16_poly_rmae  = [ error_orig_f16.mean()[0] , error_50_f16.mean()[0], error_70_f16.mean()[0], error_90_f16.mean()[0] ]
f16_knn_rmae  = [ error_orig_f16.mean()[1] , error_50_f16.mean()[1], error_70_f16.mean()[1], error_90_f16.mean()[1] ]
f16_kri_rmae  = [ error_orig_f16.mean()[2] , error_50_f16.mean()[2], error_70_f16.mean()[2], error_90_f16.mean()[2] ]
f16_svr_rmae  = [ error_orig_f16.mean()[3] , error_50_f16.mean()[3], error_70_f16.mean()[3], error_90_f16.mean()[3] ]

f20_poly_rmae  = [ error_orig_f20.mean()[0] , error_50_f20.mean()[0], error_70_f20.mean()[0], error_90_f20.mean()[0] ]
f20_knn_rmae  = [ error_orig_f20.mean()[1] , error_50_f20.mean()[1], error_70_f20.mean()[1], error_90_f20.mean()[1] ]
f20_kri_rmae  = [ error_orig_f20.mean()[2] , error_50_f20.mean()[2], error_70_f20.mean()[2], error_90_f20.mean()[2] ]
f20_svr_rmae  = [ error_orig_f20.mean()[3] , error_50_f20.mean()[3], error_70_f20.mean()[3], error_90_f20.mean()[3] ]

f24_poly_rmae  = [ error_orig_f24.mean()[0] , error_50_f24.mean()[0],  error_70_f24.mean()[0], error_90_f24.mean()[0] ]
f24_knn_rmae  = [ error_orig_f24.mean()[1] , error_50_f24.mean()[1],  error_70_f24.mean()[1], error_90_f24.mean()[1] ]
f24_kri_rmae  = [ error_orig_f24.mean()[2] , error_50_f24.mean()[2],  error_70_f24.mean()[2], error_90_f24.mean()[2] ]
f24_svr_rmae  = [ error_orig_f24.mean()[3] , error_50_f24.mean()[3], error_70_f24.mean()[3], error_90_f24.mean()[3] ]


f2_poly_std  = [ error_orig_f2.std()[0] , error_50_f2.std()[0], error_70_f2.std()[0], error_90_f2.std()[0] ]
f2_knn_std  = [ error_orig_f2.std()[1] , error_50_f2.std()[1], error_70_f2.std()[1], error_90_f2.std()[1] ]
f2_kri_std  = [ error_orig_f2.std()[2] , error_50_f2.std()[2], error_70_f2.std()[2], error_90_f2.std()[2] ]
f2_svr_std  = [ error_orig_f2.std()[3] , error_50_f2.std()[3], error_70_f2.std()[3], error_90_f2.std()[3] ]

f3_poly_std  = [ error_orig_f3.std()[0] , error_50_f3.std()[0], error_70_f3.std()[0], error_90_f3.std()[0] ]
f3_knn_std  = [ error_orig_f3.std()[1] , error_50_f3.std()[1], error_70_f3.std()[1], error_90_f3.std()[1] ]
f3_kri_std  = [ error_orig_f3.std()[2] , error_50_f3.std()[2], error_70_f3.std()[2], error_90_f3.std()[2] ]
f3_svr_std  = [ error_orig_f3.std()[3] , error_50_f3.std()[3], error_70_f3.std()[3], error_90_f3.std()[3] ]

f7_poly_std  = [ error_orig_f7.std()[0] , error_50_f7.std()[0], error_70_f7.std()[0], error_90_f7.std()[0] ]
f7_knn_std  = [ error_orig_f7.std()[1] , error_50_f7.std()[1], error_70_f7.std()[1], error_90_f7.std()[1] ]
f7_kri_std  = [ error_orig_f7.std()[2] , error_50_f7.std()[2], error_70_f7.std()[2], error_90_f7.std()[2] ]
f7_svr_std  = [ error_orig_f7.std()[3] , error_50_f7.std()[3], error_70_f7.std()[3], error_90_f7.std()[3] ]

f9_poly_std  = [ error_orig_f9.std()[0] , error_50_f9.std()[0], error_70_f9.std()[0], error_90_f9.std()[0] ]
f9_knn_std  = [ error_orig_f9.std()[1] , error_50_f9.std()[1], error_70_f9.std()[1], error_90_f9.std()[1] ]
f9_kri_std  = [ error_orig_f9.std()[2] , error_50_f9.std()[2], error_70_f9.std()[2], error_90_f9.std()[2] ]
f9_svr_std  = [ error_orig_f9.std()[3] , error_50_f9.std()[3], error_70_f9.std()[3], error_90_f9.std()[3] ]

f10_poly_std  = [ error_orig_f10.std()[0] , error_50_f10.std()[0], error_70_f10.std()[0], error_90_f10.std()[0] ]
f10_knn_std  = [ error_orig_f10.std()[1] , error_50_f10.std()[1], error_70_f10.std()[1], error_90_f10.std()[1] ]
f10_kri_std  = [ error_orig_f10.std()[2] , error_50_f10.std()[2], error_70_f10.std()[2], error_90_f10.std()[2] ]
f10_svr_std  = [ error_orig_f10.std()[3] , error_50_f10.std()[3], error_70_f10.std()[3], error_90_f10.std()[3] ]

f13_poly_std  = [ error_orig_f13.std()[0] , error_50_f13.std()[0], error_70_f13.std()[0], error_90_f13.std()[0] ]
f13_knn_std  = [ error_orig_f13.std()[1] , error_50_f13.std()[1], error_70_f13.std()[1], error_90_f13.std()[1] ]
f13_kri_std  = [ error_orig_f13.std()[2] , error_50_f13.std()[2], error_70_f13.std()[2], error_90_f13.std()[2] ]
f13_svr_std  = [ error_orig_f13.std()[3] , error_50_f13.std()[3], error_70_f13.std()[3], error_90_f13.std()[3] ]

f15_poly_std  = [ error_orig_f15.std()[0] , error_50_f15.std()[0], error_70_f15.std()[0], error_90_f15.std()[0] ]
f15_knn_std  = [ error_orig_f15.std()[1] , error_50_f15.std()[1], error_70_f15.std()[1], error_90_f15.std()[1] ]
f15_kri_std  = [ error_orig_f15.std()[2] , error_50_f15.std()[2], error_70_f15.std()[2], error_90_f15.std()[2] ]
f15_svr_std  = [ error_orig_f15.std()[3] , error_50_f15.std()[3], error_70_f15.std()[3], error_90_f15.std()[3] ]

f16_poly_std  = [ error_orig_f16.std()[0] , error_50_f16.std()[0], error_70_f16.std()[0], error_90_f16.std()[0] ]
f16_knn_std  = [ error_orig_f16.std()[1] , error_50_f16.std()[1], error_70_f16.std()[1], error_90_f16.std()[1] ]
f16_kri_std  = [ error_orig_f16.std()[2] , error_50_f16.std()[2], error_70_f16.std()[2], error_90_f16.std()[2] ]
f16_svr_std  = [ error_orig_f16.std()[3] , error_50_f16.std()[3], error_70_f16.std()[3], error_90_f16.std()[3] ]

f20_poly_std  = [ error_orig_f20.std()[0] , error_50_f20.std()[0], error_70_f20.std()[0], error_90_f20.std()[0] ]
f20_knn_std  = [ error_orig_f20.std()[1] , error_50_f20.std()[1], error_70_f20.std()[1], error_90_f20.std()[1] ]
f20_kri_std  = [ error_orig_f20.std()[2] , error_50_f20.std()[2], error_70_f20.std()[2], error_90_f20.std()[2] ]
f20_svr_std  = [ error_orig_f20.std()[3] , error_50_f20.std()[3], error_70_f20.std()[3], error_90_f20.std()[3] ]

f24_poly_std  = [ error_orig_f24.std()[0] , error_50_f24.std()[0],  error_70_f24.std()[0], error_90_f24.std()[0] ]
f24_knn_std  = [ error_orig_f24.std()[1] , error_50_f24.std()[1],  error_70_f24.std()[1], error_90_f24.std()[1] ]
f24_kri_std  = [ error_orig_f24.std()[2] , error_50_f24.std()[2],  error_70_f24.std()[2], error_90_f24.std()[2] ]
f24_svr_std  = [ error_orig_f24.std()[3] , error_50_f24.std()[3], error_70_f24.std()[3], error_90_f24.std()[3] ]

f2_poly_time  = [ 0.244, 0.171 , 0.096 , 0.0057]
f2_knn_time  = [ 0.00821 , 0.008 , 0.01 , 0.00735]
f2_kri_time  = [ 10.1, 5.5 , 6, 5.49]
f2_svr_time  = [ 0.118 , 0.061 , 0.049 , 0.038]

f3_poly_time  = [ 0.232 , 0.045 , 0.022 , 0.0052 ]
f3_knn_time  = [ 0.0185 , 0.008 , 0.0079 , 0.0083 ]
f3_kri_time  = [ 6.97 , 5.3, 3.6 , 2.9 ]
f3_svr_time  = [ 0.242 , 0.071 , 0.058 , 0.047 ]

f7_poly_time  = [ 0.574 , 0.044 , 0.022, 0.0061 ]
f7_knn_time  = [ 0.0201 , 0.0082 , 0.0078 , 0.0083 ]
f7_kri_time  = [ 10.5 , 7 , 4.2 ,  3.2]
f7_svr_time  = [ 0.242 , 0.072 , 0.128 , 0.042 ]

f9_poly_time  = [ 0.212 , 0.03 , 0.0150 , 0.0062 ]
f9_knn_time  = [ 0.0254 , 0.0089 , 0.0077 , 0.0091 ]
f9_kri_time  = [ 15.4 , 5.5 , 4.9 , 3.3 ]
f9_svr_time  = [ 0.22 , 0.0613 , 0.048 , 0.038 ]

f10_poly_time  = [ 2.21 , 0.705 , 0.128 , 0.0064 ]
f10_knn_time  = [ 0.0189 , 0.0079 , 0.0088 , 0.0085 ]
f10_kri_time  = [ 8.58 , 6.5 ,2.3 ,2 ]
f10_svr_time  = [ 0.219 , 0.061 , 0.052 ,0.038 ]

f13_poly_time  = [  0.47, 0.04 , 0.022 , 0.006]
f13_knn_time  = [ 0.0208 , 0.00775 , 0.0076 , 0.008 ]
f13_kri_time  = [ 9 , 5.9 , 2.1 , 2.1 ]
f13_svr_time  = [ 0.253 , 0.0754 , 0.06 , 0.042 ]

f15_poly_time  = [ 0.235 , 0.037 , 0.015 , 0.0061 ]
f15_knn_time  = [ 0.0189 , 0.008 , 0.0076 , 0.0088]
f15_kri_time  = [ 8.29 , 7 , 4.2 , 2.9  ]
f15_svr_time  = [ 0.246 , 0.104 , 0.107 , 0.048 ]

f16_poly_time  = [ 0.182 , 0.0276 , 0.0136 , 0.006 ]
f16_knn_time  = [ 0.0246 , 0.022 , 0.013 , 0.019 ]
f16_kri_time  = [ 6.5 , 4.41 , 3.1 , 3.1 ]
f16_svr_time  = [ 0.225 , 0.114 , 0.049 , 0.037 ]

f20_poly_time  = [ 0.371 , 0.031 , 0.12 , 0.0081 ]
f20_knn_time  = [ 0.0182 , 0.008 , 0.0071 , 0.0086 ]
f20_kri_time  = [ 10.3 , 5.4 , 6, 3.5 ]
f20_svr_time  = [ 0.219 , 0.061 , 0.048 , 0.038 ]

f24_poly_time  = [0.523 , 0.038 , 0.015 , 0.0082 ]
f24_knn_time  = [ 0.0632 , 0.027 , 0.0074 , 0.0085 ]
f24_kri_time  = [ 8.4 , 5.4 , 5.9 , 4.2 ]
f24_svr_time  = [ 0.254,0.127,0.097 , 0.039 ]

# %% [markdown]
# ## 50 D 50 %

# %%
cols = ['Noise Level : 5 %','Noise Level : 10 %','Noise Level : 20 %']
rows = ['F(2,3,7,9,10)','F(13,15,16,20,24)']

f, axarr = plt.subplots(2, 5,figsize=(15,6))


line = []
line.append(axarr[0,0].errorbar(f2_poly_rmae , f2_poly_time  , marker='v', 
                     color='r',label='ELN', fillstyle='none',markersize=8)[0])
line.append(axarr[0,0].errorbar(f2_kri_rmae, f2_kri_time,  marker='s', 
                     color='b',label='Kriging',fillstyle='none',markersize=8)[0])
line.append(axarr[0,0].errorbar(f2_svr_rmae , f2_svr_time,   marker='*', 
                     color='g',label='SVR',fillstyle='none',markersize=8)[0])

axarr[0,0].set_yscale('log',basey=2)
axarr[0,0].set_xscale('log',basex=2)
axarr[0,0].set_ylabel('Time (Seconds)',size=12)
axarr[0,0].grid(which='major')
axarr[0,0].set_title('F2')
axarr[0,0].tick_params(labelsize=12)

axarr[0,1].errorbar( f3_poly_rmae, f3_poly_time , marker='v' ,  color='r', fillstyle='none',markersize=8)
axarr[0,1].errorbar(f3_poly_rmae , f3_kri_time,  marker='s' , color='b', fillstyle='none',markersize=8)
axarr[0,1].errorbar(f3_poly_rmae , f3_svr_time, marker='*' , color='g', fillstyle='none',markersize=8)

axarr[0,1].set_yscale('log',basey=2)
axarr[0,1].set_xscale('log',basex=2)
axarr[0,1].grid(which='major')
axarr[0,1].set_title('F3')
axarr[0,1].tick_params(labelsize=12)

axarr[0,2].errorbar(f7_poly_rmae , f7_poly_time , marker='v' ,  color='r', fillstyle='none',markersize=8)
axarr[0,2].errorbar(f7_poly_rmae , f7_kri_time,  marker='s' , color='b', fillstyle='none',markersize=8)
axarr[0,2].errorbar(f7_poly_rmae , f7_svr_time,  marker='*' , color='g', fillstyle='none',markersize=8)

axarr[0,2].set_yscale('log',basey=2)
axarr[0,2].set_xscale('log',basex=2)
axarr[0,2].grid(which='major')
axarr[0,2].set_title('F7')
axarr[0,2].tick_params(labelsize=12)

axarr[0,3].errorbar(f9_poly_rmae , f9_poly_time, marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[0,3].errorbar(f9_poly_rmae , f9_kri_time,  marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[0,3].errorbar(f9_poly_rmae, f9_svr_time,   marker='*' , color='g', fillstyle='none',markersize=8)

axarr[0,3].set_yscale('log',basey=2)
axarr[0,3].set_xscale('log',basex=2)
axarr[0,3].grid(which='major')
axarr[0,3].set_title('F9')
axarr[0,3].tick_params(labelsize=12)


axarr[0,4].errorbar(f10_poly_rmae, f10_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[0,4].errorbar(f10_poly_rmae , f10_kri_time,  marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[0,4].errorbar(f10_poly_rmae, f10_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[0,4].set_yscale('log',basey=2)
axarr[0,4].set_xscale('log',basex=2)
axarr[0,4].grid(which='major')
axarr[0,4].set_title('F10')
axarr[0,4].tick_params(labelsize=12)

axarr[1,0].errorbar(f13_poly_rmae, f13_poly_time,   marker='v' ,  color='r', fillstyle='none',markersize=8)
axarr[1,0].errorbar(f13_poly_rmae, f13_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,0].errorbar(f13_poly_rmae, f13_svr_time, marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,0].set_xlabel('RMAE (%)',size=12)
axarr[1,0].set_yscale('log',basey=2)
axarr[1,0].set_xscale('log',basex=2)
axarr[1,0].set_ylabel('Time (Seconds)',size=12)
axarr[1,0].grid(which='major')
axarr[1,0].set_title('F13')
axarr[1,0].tick_params(labelsize=12)

axarr[1,1].errorbar(f15_poly_rmae, f15_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,1].errorbar(f15_poly_rmae, f15_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,1].errorbar(f15_poly_rmae, f15_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,1].set_xlabel('RMAE (%)',size=12)
axarr[1,1].set_yscale('log',basey=2)
axarr[1,1].set_xscale('log',basex=2)
axarr[1,1].grid(which='major')
axarr[1,1].set_title('F15')
axarr[1,1].tick_params(labelsize=12)

axarr[1,2].errorbar(f16_poly_rmae, f16_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,2].errorbar(f16_poly_rmae, f16_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,2].errorbar(f16_poly_rmae,f16_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,2].set_xlabel('RMAE (%)',size=12)
axarr[1,2].set_yscale('log',basey=2)
axarr[1,2].set_xscale('log',basex=2)
axarr[1,2].grid(which='major')
axarr[1,2].set_title('F16')
axarr[1,2].tick_params(labelsize=12)

axarr[1,3].errorbar(f20_poly_rmae, f20_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,3].errorbar(f20_poly_rmae, f20_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,3].errorbar(f20_poly_rmae, f20_svr_time,   marker='*' , color='g', fillstyle='none',markersize=8)

axarr[1,3].set_xlabel('RMAE (%)',size=12)
axarr[1,3].set_yscale('log',basey=2)
axarr[1,3].set_xscale('log',basex=2)
axarr[1,3].grid(which='major')
axarr[1,3].set_title('F20')
axarr[1,3].tick_params(labelsize=12)

axarr[1,4].errorbar(f24_poly_rmae, f24_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,4].errorbar(f24_poly_rmae, f24_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,4].errorbar(f24_poly_rmae, f24_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,4].set_xlabel('RMAE (%)',size=12)
axarr[1,4].set_yscale('log',basey=2)
axarr[1,4].set_xscale('log',basex=2)
axarr[1,4].grid(which='major')
axarr[1,4].set_title('F24')
axarr[1,4].tick_params(labelsize=12)

pad = 10



f.tight_layout()   
f.legend(line, ['ELN', 'Kriging', 'SVR'], loc='upper left', fontsize=12 , ncol=3 , bbox_to_anchor=(0.37, 1.07),fancybox=True  )

plt.show()
f.savefig("50 D.pdf",bbox_inches='tight')

# %% [markdown]
# ## 100 D

# %%
orig_path = "Surrogate Modeling\\Original\\Modeling Accuracy\\100 D\\Results\\"
orig_f2 = pd.read_csv(orig_path+'F2_Accuracy.csv', index_col=0)
orig_f3 = pd.read_csv(orig_path+'F3_Accuracy.csv', index_col=0)
orig_f7 = pd.read_csv(orig_path+'F7_Accuracy.csv', index_col=0)
orig_f9 = pd.read_csv(orig_path+'F9_Accuracy.csv', index_col=0)
orig_f10 = pd.read_csv(orig_path+'F10_Accuracy.csv', index_col=0)
orig_f13 = pd.read_csv(orig_path+'F13_Accuracy.csv', index_col=0)
orig_f15 = pd.read_csv(orig_path+'F15_Accuracy.csv', index_col=0)
orig_f16 = pd.read_csv(orig_path+'F16_Accuracy.csv', index_col=0)
orig_f20 = pd.read_csv(orig_path+'F20_Accuracy.csv', index_col=0)
orig_f24 = pd.read_csv(orig_path+'F24_Accuracy.csv', index_col=0)

lat_50_path = "Surrogate Modeling\\Latent\\Modeling Accuracy\\50 %\\100 D\\Results\\"
lat_50_f2 = pd.read_csv(lat_50_path+'F2_Accuracy.csv', index_col=0)
lat_50_f3 = pd.read_csv(lat_50_path+'F3_Accuracy.csv', index_col=0)
lat_50_f7 = pd.read_csv(lat_50_path+'F7_Accuracy.csv', index_col=0)
lat_50_f9 = pd.read_csv(lat_50_path+'F9_Accuracy.csv', index_col=0)
lat_50_f10 = pd.read_csv(lat_50_path+'F10_Accuracy.csv', index_col=0)
lat_50_f13 = pd.read_csv(lat_50_path+'F13_Accuracy.csv', index_col=0)
lat_50_f15 = pd.read_csv(lat_50_path+'F15_Accuracy.csv', index_col=0)
lat_50_f16 = pd.read_csv(lat_50_path+'F16_Accuracy.csv', index_col=0)
lat_50_f20 = pd.read_csv(lat_50_path+'F20_Accuracy.csv', index_col=0)
lat_50_f24 = pd.read_csv(lat_50_path+'F24_Accuracy.csv', index_col=0)



lat_70_path = "Surrogate Modeling\\Latent\\Modeling Accuracy\\70 %\\100 D\\Results\\"
lat_70_f2 = pd.read_csv(lat_70_path+'F2_Accuracy.csv', index_col=0)
lat_70_f3 = pd.read_csv(lat_70_path+'F3_Accuracy.csv', index_col=0)
lat_70_f7 = pd.read_csv(lat_70_path+'F7_Accuracy.csv', index_col=0)
lat_70_f9 = pd.read_csv(lat_70_path+'F9_Accuracy.csv', index_col=0)
lat_70_f10 = pd.read_csv(lat_70_path+'F10_Accuracy.csv', index_col=0)
lat_70_f13 = pd.read_csv(lat_70_path+'F13_Accuracy.csv', index_col=0)
lat_70_f15 = pd.read_csv(lat_70_path+'F15_Accuracy.csv', index_col=0)
lat_70_f16 = pd.read_csv(lat_70_path+'F16_Accuracy.csv', index_col=0)
lat_70_f20 = pd.read_csv(lat_70_path+'F20_Accuracy.csv', index_col=0)
lat_70_f24 = pd.read_csv(lat_70_path+'F24_Accuracy.csv', index_col=0)


lat_90_path = "Surrogate Modeling\\Latent\\Modeling Accuracy\\90 %\\100 D\\Results\\"
lat_90_f2 = pd.read_csv(lat_90_path+'F2_Accuracy.csv', index_col=0)
lat_90_f3 = pd.read_csv(lat_90_path+'F3_Accuracy.csv', index_col=0)
lat_90_f7 = pd.read_csv(lat_90_path+'F7_Accuracy.csv', index_col=0)
lat_90_f9 = pd.read_csv(lat_90_path+'F9_Accuracy.csv', index_col=0)
lat_90_f10 = pd.read_csv(lat_90_path+'F10_Accuracy.csv', index_col=0)
lat_90_f13 = pd.read_csv(lat_90_path+'F13_Accuracy.csv', index_col=0)
lat_90_f15 = pd.read_csv(lat_90_path+'F15_Accuracy.csv', index_col=0)
lat_90_f16 = pd.read_csv(lat_90_path+'F16_Accuracy.csv', index_col=0)
lat_90_f20 = pd.read_csv(lat_90_path+'F20_Accuracy.csv', index_col=0)
lat_90_f24 = pd.read_csv(lat_90_path+'F24_Accuracy.csv', index_col=0)

# %%
error_orig_f2 = pd.DataFrame(data= [(abs(orig_f2['True']-orig_f2['ELN'])/abs(orig_f2['True'])) * 100 , 
                   (abs(orig_f2['True']-orig_f2['KNN'])/abs(orig_f2['True'])) * 100, 
                   (abs(orig_f2['True']-orig_f2['Kri'])/abs(orig_f2['True'])) * 100,
                    (abs(orig_f2['True']-orig_f2['SVR'])/abs(orig_f2['True'])) * 100]).T
error_orig_f2.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']


error_orig_f3 = pd.DataFrame(data= [(abs(orig_f3['True']-orig_f3['ELN'])/abs(orig_f3['True'])) * 100 , 
                   (abs(orig_f3['True']-orig_f3['KNN'])/abs(orig_f3['True'])) * 100, 
                   (abs(orig_f3['True']-orig_f3['Kri'])/abs(orig_f3['True'])) * 100,
                    (abs(orig_f3['True']-orig_f3['SVR'])/abs(orig_f3['True'])) * 100]).T
error_orig_f3.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f7 = pd.DataFrame(data= [(abs(orig_f7['True']-orig_f7['ELN'])/abs(orig_f7['True'])) * 100 , 
                   (abs(orig_f7['True']-orig_f7['KNN'])/abs(orig_f7['True'])) * 100, 
                   (abs(orig_f7['True']-orig_f7['Kri'])/abs(orig_f7['True'])) * 100,
                    (abs(orig_f7['True']-orig_f7['SVR'])/abs(orig_f7['True'])) * 100]).T
error_orig_f7.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f9 = pd.DataFrame(data= [(abs(orig_f9['True']-orig_f9['ELN'])/abs(orig_f9['True'])) * 100 , 
                   (abs(orig_f9['True']-orig_f9['KNN'])/abs(orig_f9['True'])) * 100, 
                   (abs(orig_f9['True']-orig_f9['Kri'])/abs(orig_f9['True'])) * 100,
                    (abs(orig_f9['True']-orig_f9['SVR'])/abs(orig_f9['True'])) * 100]).T
error_orig_f9.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f10 = pd.DataFrame(data= [(abs(orig_f10['True']-orig_f10['ELN'])/abs(orig_f10['True'])) * 100 , 
                   (abs(orig_f10['True']-orig_f10['KNN'])/abs(orig_f10['True'])) * 100, 
                   (abs(orig_f10['True']-orig_f10['Kri'])/abs(orig_f10['True'])) * 100,
                    (abs(orig_f10['True']-orig_f10['SVR'])/abs(orig_f10['True'])) * 100]).T
error_orig_f10.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f13 = pd.DataFrame(data= [(abs(orig_f13['True']-orig_f13['ELN'])/abs(orig_f13['True'])) * 100 , 
                   (abs(orig_f13['True']-orig_f13['KNN'])/abs(orig_f13['True'])) * 100, 
                   (abs(orig_f13['True']-orig_f13['Kri'])/abs(orig_f13['True'])) * 100,
                    (abs(orig_f13['True']-orig_f13['SVR'])/abs(orig_f13['True'])) * 100]).T
error_orig_f13.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f15 = pd.DataFrame(data= [(abs(orig_f15['True']-orig_f15['ELN'])/abs(orig_f15['True'])) * 100 , 
                   (abs(orig_f15['True']-orig_f15['KNN'])/abs(orig_f15['True'])) * 100, 
                   (abs(orig_f15['True']-orig_f15['Kri'])/abs(orig_f15['True'])) * 100,
                    (abs(orig_f15['True']-orig_f15['SVR'])/abs(orig_f15['True'])) * 100]).T
error_orig_f15.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f16 = pd.DataFrame(data= [(abs(orig_f16['True']-orig_f16['ELN'])/abs(orig_f16['True'])) * 100 , 
                   (abs(orig_f16['True']-orig_f16['KNN'])/abs(orig_f16['True'])) * 100, 
                   (abs(orig_f16['True']-orig_f16['Kri'])/abs(orig_f16['True'])) * 100,
                    (abs(orig_f16['True']-orig_f16['SVR'])/abs(orig_f16['True'])) * 100]).T
error_orig_f16.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f20 = pd.DataFrame(data= [(abs(orig_f20['True']-orig_f20['ELN'])/abs(orig_f20['True'])) * 100 , 
                   (abs(orig_f20['True']-orig_f20['KNN'])/abs(orig_f20['True'])) * 100, 
                   (abs(orig_f20['True']-orig_f20['Kri'])/abs(orig_f20['True'])) * 100,
                    (abs(orig_f20['True']-orig_f20['SVR'])/abs(orig_f20['True'])) * 100]).T
error_orig_f20.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f24 = pd.DataFrame(data= [(abs(orig_f24['True']-orig_f24['ELN'])/abs(orig_f20['True'])) * 100 , 
                   (abs(orig_f24['True']-orig_f24['KNN'])/abs(orig_f24['True'])) * 100, 
                   (abs(orig_f24['True']-orig_f24['Kri'])/abs(orig_f24['True'])) * 100,
                    (abs(orig_f24['True']-orig_f24['SVR'])/abs(orig_f24['True'])) * 100]).T
error_orig_f24.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_50_f2 = pd.DataFrame(data= [(abs(lat_50_f2['True']-lat_50_f2['ELN'])/abs(lat_50_f2['True'])) * 100 , 
                   (abs(lat_50_f2['True']-lat_50_f2['KNN'])/abs(lat_50_f2['True'])) * 100, 
                   (abs(lat_50_f2['True']-lat_50_f2['Kri'])/abs(lat_50_f2['True'])) * 100,
                    (abs(lat_50_f2['True']-lat_50_f2['SVR'])/abs(lat_50_f2['True'])) * 100]).T
error_50_f2.columns = ['ELN','KNN','Kri','SVR']

error_50_f3 = pd.DataFrame(data= [(abs(lat_50_f3['True']-lat_50_f3['ELN'])/abs(lat_50_f3['True'])) * 100 , 
                   (abs(lat_50_f3['True']-lat_50_f3['KNN'])/abs(lat_50_f3['True'])) * 100, 
                   (abs(lat_50_f3['True']-lat_50_f3['Kri'])/abs(lat_50_f3['True'])) * 100,
                    (abs(lat_50_f3['True']-lat_50_f3['SVR'])/abs(lat_50_f3['True'])) * 100]).T
error_50_f3.columns = ['ELN','KNN','Kri','SVR']

error_50_f7 = pd.DataFrame(data= [(abs(lat_50_f7['True']-lat_50_f7['ELN'])/abs(lat_50_f7['True'])) * 100 , 
                   (abs(lat_50_f7['True']-lat_50_f7['KNN'])/abs(lat_50_f7['True'])) * 100, 
                   (abs(lat_50_f7['True']-lat_50_f7['Kri'])/abs(lat_50_f7['True'])) * 100,
                    (abs(lat_50_f7['True']-lat_50_f7['SVR'])/abs(lat_50_f7['True'])) * 100]).T
error_50_f7.columns = ['ELN','KNN','Kri','SVR']

error_50_f9 = pd.DataFrame(data= [(abs(lat_50_f9['True']-lat_50_f9['ELN'])/abs(lat_50_f9['True'])) * 100 , 
                   (abs(lat_50_f9['True']-lat_50_f9['KNN'])/abs(lat_50_f9['True'])) * 100, 
                   (abs(lat_50_f9['True']-lat_50_f9['Kri'])/abs(lat_50_f9['True'])) * 100,
                    (abs(lat_50_f9['True']-lat_50_f9['SVR'])/abs(lat_50_f9['True'])) * 100]).T
error_50_f9.columns = ['ELN','KNN','Kri','SVR']

error_50_f10 = pd.DataFrame(data= [(abs(lat_50_f10['True']-lat_50_f10['ELN'])/abs(lat_50_f10['True'])) * 100 , 
                   (abs(lat_50_f10['True']-lat_50_f10['KNN'])/abs(lat_50_f10['True'])) * 100, 
                   (abs(lat_50_f10['True']-lat_50_f10['Kri'])/abs(lat_50_f10['True'])) * 100,
                    (abs(lat_50_f10['True']-lat_50_f10['SVR'])/abs(lat_50_f10['True'])) * 100]).T
error_50_f10.columns = ['ELN','KNN','Kri','SVR']

error_50_f13 = pd.DataFrame(data= [(abs(lat_50_f13['True']-lat_50_f13['ELN'])/abs(lat_50_f13['True'])) * 100 , 
                   (abs(lat_50_f13['True']-lat_50_f13['KNN'])/abs(lat_50_f13['True'])) * 100, 
                   (abs(lat_50_f13['True']-lat_50_f13['Kri'])/abs(lat_50_f13['True'])) * 100,
                    (abs(lat_50_f13['True']-lat_50_f13['SVR'])/abs(lat_50_f13['True'])) * 100]).T
error_50_f13.columns = ['ELN','KNN','Kri','SVR']

error_50_f15 = pd.DataFrame(data= [(abs(lat_50_f15['True']-lat_50_f15['ELN'])/abs(lat_50_f15['True'])) * 100 , 
                   (abs(lat_50_f15['True']-lat_50_f15['KNN'])/abs(lat_50_f15['True'])) * 100, 
                   (abs(lat_50_f15['True']-lat_50_f15['Kri'])/abs(lat_50_f15['True'])) * 100,
                    (abs(lat_50_f15['True']-lat_50_f15['SVR'])/abs(lat_50_f15['True'])) * 100]).T
error_50_f15.columns = ['ELN','KNN','Kri','SVR']

error_50_f16 = pd.DataFrame(data= [(abs(lat_50_f16['True']-lat_50_f16['ELN'])/abs(lat_50_f16['True'])) * 100 , 
                   (abs(lat_50_f16['True']-lat_50_f16['KNN'])/abs(lat_50_f16['True'])) * 100, 
                   (abs(lat_50_f16['True']-lat_50_f16['Kri'])/abs(lat_50_f16['True'])) * 100,
                    (abs(lat_50_f16['True']-lat_50_f16['SVR'])/abs(lat_50_f16['True'])) * 100]).T
error_50_f16.columns = ['ELN','KNN','Kri','SVR']

error_50_f20 = pd.DataFrame(data= [(abs(lat_50_f20['True']-lat_50_f20['ELN'])/abs(lat_50_f20['True'])) * 100 , 
                   (abs(lat_50_f20['True']-lat_50_f20['KNN'])/abs(lat_50_f20['True'])) * 100, 
                   (abs(lat_50_f20['True']-lat_50_f20['Kri'])/abs(lat_50_f20['True'])) * 100,
                    (abs(lat_50_f20['True']-lat_50_f20['SVR'])/abs(lat_50_f20['True'])) * 100]).T
error_50_f20.columns = ['ELN','KNN','Kri','SVR']

error_50_f24 = pd.DataFrame(data= [(abs(lat_50_f24['True']-lat_50_f24['ELN'])/abs(lat_50_f24['True'])) * 100 , 
                   (abs(lat_50_f24['True']-lat_50_f24['KNN'])/abs(lat_50_f24['True'])) * 100, 
                   (abs(lat_50_f24['True']-lat_50_f24['Kri'])/abs(lat_50_f24['True'])) * 100,
                    (abs(lat_50_f24['True']-lat_50_f24['SVR'])/abs(lat_50_f24['True'])) * 100]).T
error_50_f24.columns = ['ELN','KNN','Kri','SVR']


error_70_f2 = pd.DataFrame(data= [(abs(lat_70_f2['True']-lat_70_f2['ELN'])/abs(lat_70_f2['True'])) * 100 , 
                   (abs(lat_70_f2['True']-lat_70_f2['KNN'])/abs(lat_70_f2['True'])) * 100, 
                   (abs(lat_70_f2['True']-lat_70_f2['Kri'])/abs(lat_70_f2['True'])) * 100,
                    (abs(lat_70_f2['True']-lat_70_f2['SVR'])/abs(lat_70_f2['True'])) * 100]).T
error_70_f2.columns = ['ELN','KNN','Kri','SVR']

error_70_f3 = pd.DataFrame(data= [(abs(lat_70_f3['True']-lat_70_f3['ELN'])/abs(lat_70_f3['True'])) * 100 , 
                   (abs(lat_70_f3['True']-lat_70_f3['KNN'])/abs(lat_70_f3['True'])) * 100, 
                   (abs(lat_70_f3['True']-lat_70_f3['Kri'])/abs(lat_70_f3['True'])) * 100,
                    (abs(lat_70_f3['True']-lat_70_f3['SVR'])/abs(lat_70_f3['True'])) * 100]).T
error_70_f3.columns = ['ELN','KNN','Kri','SVR']

error_70_f7 = pd.DataFrame(data= [(abs(lat_70_f7['True']-lat_70_f7['ELN'])/abs(lat_70_f7['True'])) * 100 , 
                   (abs(lat_70_f7['True']-lat_70_f7['KNN'])/abs(lat_70_f7['True'])) * 100, 
                   (abs(lat_70_f7['True']-lat_70_f7['Kri'])/abs(lat_70_f7['True'])) * 100,
                    (abs(lat_70_f7['True']-lat_70_f7['SVR'])/abs(lat_70_f7['True'])) * 100]).T
error_70_f7.columns = ['ELN','KNN','Kri','SVR']

error_70_f9 = pd.DataFrame(data= [(abs(lat_70_f9['True']-lat_70_f9['ELN'])/abs(lat_70_f9['True'])) * 100 , 
                   (abs(lat_70_f9['True']-lat_70_f9['KNN'])/abs(lat_70_f9['True'])) * 100, 
                   (abs(lat_70_f9['True']-lat_70_f9['Kri'])/abs(lat_70_f9['True'])) * 100,
                    (abs(lat_70_f9['True']-lat_70_f9['SVR'])/abs(lat_70_f9['True'])) * 100]).T
error_70_f9.columns = ['ELN','KNN','Kri','SVR']

error_70_f10 = pd.DataFrame(data= [(abs(lat_70_f10['True']-lat_70_f10['ELN'])/abs(lat_70_f10['True'])) * 100 , 
                   (abs(lat_70_f10['True']-lat_70_f10['KNN'])/abs(lat_70_f10['True'])) * 100, 
                   (abs(lat_70_f10['True']-lat_70_f10['Kri'])/abs(lat_70_f10['True'])) * 100,
                    (abs(lat_70_f10['True']-lat_70_f10['SVR'])/abs(lat_70_f10['True'])) * 100]).T
error_70_f10.columns = ['ELN','KNN','Kri','SVR']

error_70_f13 = pd.DataFrame(data= [(abs(lat_70_f13['True']-lat_70_f13['ELN'])/abs(lat_70_f13['True'])) * 100 , 
                   (abs(lat_70_f13['True']-lat_70_f13['KNN'])/abs(lat_70_f13['True'])) * 100, 
                   (abs(lat_70_f13['True']-lat_70_f13['Kri'])/abs(lat_70_f13['True'])) * 100,
                    (abs(lat_70_f13['True']-lat_70_f13['SVR'])/abs(lat_70_f13['True'])) * 100]).T
error_70_f13.columns = ['ELN','KNN','Kri','SVR']

error_70_f15 = pd.DataFrame(data= [(abs(lat_70_f15['True']-lat_70_f15['ELN'])/abs(lat_70_f15['True'])) * 100 , 
                   (abs(lat_70_f15['True']-lat_70_f15['KNN'])/abs(lat_70_f15['True'])) * 100, 
                   (abs(lat_70_f15['True']-lat_70_f15['Kri'])/abs(lat_70_f15['True'])) * 100,
                    (abs(lat_70_f15['True']-lat_70_f15['SVR'])/abs(lat_70_f15['True'])) * 100]).T
error_70_f15.columns = ['ELN','KNN','Kri','SVR']

error_70_f16 = pd.DataFrame(data= [(abs(lat_70_f16['True']-lat_70_f16['ELN'])/abs(lat_70_f16['True'])) * 100 , 
                   (abs(lat_70_f16['True']-lat_70_f16['KNN'])/abs(lat_70_f16['True'])) * 100, 
                   (abs(lat_70_f16['True']-lat_70_f16['Kri'])/abs(lat_70_f16['True'])) * 100,
                    (abs(lat_70_f16['True']-lat_70_f16['SVR'])/abs(lat_70_f16['True'])) * 100]).T
error_70_f16.columns = ['ELN','KNN','Kri','SVR']

error_70_f20 = pd.DataFrame(data= [(abs(lat_70_f20['True']-lat_70_f20['ELN'])/abs(lat_70_f20['True'])) * 100 , 
                   (abs(lat_70_f20['True']-lat_70_f20['KNN'])/abs(lat_70_f20['True'])) * 100, 
                   (abs(lat_70_f20['True']-lat_70_f20['Kri'])/abs(lat_70_f20['True'])) * 100,
                    (abs(lat_70_f20['True']-lat_70_f20['SVR'])/abs(lat_70_f20['True'])) * 100]).T
error_70_f20.columns = ['ELN','KNN','Kri','SVR']

error_70_f24 = pd.DataFrame(data= [(abs(lat_70_f24['True']-lat_70_f24['ELN'])/abs(lat_70_f24['True'])) * 100 , 
                   (abs(lat_70_f24['True']-lat_70_f24['KNN'])/abs(lat_70_f24['True'])) * 100, 
                   (abs(lat_70_f24['True']-lat_70_f24['Kri'])/abs(lat_70_f24['True'])) * 100,
                    (abs(lat_70_f24['True']-lat_70_f24['SVR'])/abs(lat_70_f24['True'])) * 100]).T
error_70_f24.columns = ['ELN','KNN','Kri','SVR']



error_90_f2 = pd.DataFrame(data= [(abs(lat_90_f2['True']-lat_90_f2['ELN'])/abs(lat_90_f2['True'])) * 100 , 
                   (abs(lat_90_f2['True']-lat_90_f2['KNN'])/abs(lat_90_f2['True'])) * 100, 
                   (abs(lat_90_f2['True']-lat_90_f2['Kri'])/abs(lat_90_f2['True'])) * 100,
                    (abs(lat_90_f2['True']-lat_90_f2['SVR'])/abs(lat_90_f2['True'])) * 100]).T
error_90_f2.columns = ['ELN','KNN','Kri','SVR']

error_90_f3 = pd.DataFrame(data= [(abs(lat_90_f3['True']-lat_90_f3['ELN'])/abs(lat_90_f3['True'])) * 100 , 
                   (abs(lat_90_f3['True']-lat_90_f3['KNN'])/abs(lat_90_f3['True'])) * 100, 
                   (abs(lat_90_f3['True']-lat_90_f3['Kri'])/abs(lat_90_f3['True'])) * 100,
                    (abs(lat_90_f3['True']-lat_90_f3['SVR'])/abs(lat_90_f3['True'])) * 100]).T
error_90_f3.columns = ['ELN','KNN','Kri','SVR']

error_90_f7 = pd.DataFrame(data= [(abs(lat_90_f7['True']-lat_90_f7['ELN'])/abs(lat_90_f7['True'])) * 100 , 
                   (abs(lat_90_f7['True']-lat_90_f7['KNN'])/abs(lat_90_f7['True'])) * 100, 
                   (abs(lat_90_f7['True']-lat_90_f7['Kri'])/abs(lat_90_f7['True'])) * 100,
                    (abs(lat_90_f7['True']-lat_90_f7['SVR'])/abs(lat_90_f7['True'])) * 100]).T
error_90_f7.columns = ['ELN','KNN','Kri','SVR']

error_90_f9 = pd.DataFrame(data= [(abs(lat_90_f9['True']-lat_90_f9['ELN'])/abs(lat_90_f9['True'])) * 100 , 
                   (abs(lat_90_f9['True']-lat_90_f9['KNN'])/abs(lat_90_f9['True'])) * 100, 
                   (abs(lat_90_f9['True']-lat_90_f9['Kri'])/abs(lat_90_f9['True'])) * 100,
                    (abs(lat_90_f9['True']-lat_90_f9['SVR'])/abs(lat_90_f9['True'])) * 100]).T
error_90_f9.columns = ['ELN','KNN','Kri','SVR']

error_90_f10 = pd.DataFrame(data= [(abs(lat_90_f10['True']-lat_90_f10['ELN'])/abs(lat_90_f10['True'])) * 100 , 
                   (abs(lat_90_f10['True']-lat_90_f10['KNN'])/abs(lat_90_f10['True'])) * 100, 
                   (abs(lat_90_f10['True']-lat_90_f10['Kri'])/abs(lat_90_f10['True'])) * 100,
                    (abs(lat_90_f10['True']-lat_90_f10['SVR'])/abs(lat_90_f10['True'])) * 100]).T
error_90_f10.columns = ['ELN','KNN','Kri','SVR']

error_90_f13 = pd.DataFrame(data= [(abs(lat_90_f13['True']-lat_90_f13['ELN'])/abs(lat_90_f13['True'])) * 100 , 
                   (abs(lat_90_f13['True']-lat_90_f13['KNN'])/abs(lat_90_f13['True'])) * 100, 
                   (abs(lat_90_f13['True']-lat_90_f13['Kri'])/abs(lat_90_f13['True'])) * 100,
                    (abs(lat_90_f13['True']-lat_90_f13['SVR'])/abs(lat_90_f13['True'])) * 100]).T
error_90_f13.columns = ['ELN','KNN','Kri','SVR']

error_90_f15 = pd.DataFrame(data= [(abs(lat_90_f15['True']-lat_90_f15['ELN'])/abs(lat_90_f15['True'])) * 100 , 
                   (abs(lat_90_f15['True']-lat_90_f15['KNN'])/abs(lat_90_f15['True'])) * 100, 
                   (abs(lat_90_f15['True']-lat_90_f15['Kri'])/abs(lat_90_f15['True'])) * 100,
                    (abs(lat_90_f15['True']-lat_90_f15['SVR'])/abs(lat_90_f15['True'])) * 100]).T
error_90_f15.columns = ['ELN','KNN','Kri','SVR']

error_90_f16 = pd.DataFrame(data= [(abs(lat_90_f16['True']-lat_90_f16['ELN'])/abs(lat_90_f16['True'])) * 100 , 
                   (abs(lat_90_f16['True']-lat_90_f16['KNN'])/abs(lat_90_f16['True'])) * 100, 
                   (abs(lat_90_f16['True']-lat_90_f16['Kri'])/abs(lat_90_f16['True'])) * 100,
                    (abs(lat_90_f16['True']-lat_90_f16['SVR'])/abs(lat_90_f16['True'])) * 100]).T
error_90_f16.columns = ['ELN','KNN','Kri','SVR']

error_90_f20 = pd.DataFrame(data= [(abs(lat_90_f20['True']-lat_90_f20['ELN'])/abs(lat_90_f20['True'])) * 100 , 
                   (abs(lat_90_f20['True']-lat_90_f20['KNN'])/abs(lat_90_f20['True'])) * 100, 
                   (abs(lat_90_f20['True']-lat_90_f20['Kri'])/abs(lat_90_f20['True'])) * 100,
                    (abs(lat_90_f20['True']-lat_90_f20['SVR'])/abs(lat_90_f20['True'])) * 100]).T
error_90_f20.columns = ['ELN','KNN','Kri','SVR']

error_90_f24 = pd.DataFrame(data= [(abs(lat_90_f24['True']-lat_90_f24['ELN'])/abs(lat_90_f24['True'])) * 100 , 
                   (abs(lat_90_f24['True']-lat_90_f24['KNN'])/abs(lat_90_f24['True'])) * 100, 
                   (abs(lat_90_f24['True']-lat_90_f24['Kri'])/abs(lat_90_f24['True'])) * 100,
                    (abs(lat_90_f24['True']-lat_90_f24['SVR'])/abs(lat_90_f24['True'])) * 100]).T
error_90_f24.columns = ['ELN','KNN','Kri','SVR']

# %%
f2_poly_rmae  = [ error_orig_f2.mean()[0] , error_50_f2.mean()[0], error_70_f2.mean()[0], error_90_f2.mean()[0] ]
f2_knn_rmae  = [ error_orig_f2.mean()[1] , error_50_f2.mean()[1], error_70_f2.mean()[1], error_90_f2.mean()[1] ]
f2_kri_rmae  = [ error_orig_f2.mean()[2] , error_50_f2.mean()[2], error_70_f2.mean()[2], error_90_f2.mean()[2] ]
f2_svr_rmae  = [ error_orig_f2.mean()[3] , error_50_f2.mean()[3], error_70_f2.mean()[3], error_90_f2.mean()[3] ]

f3_poly_rmae  = [ error_orig_f3.mean()[0] , error_50_f3.mean()[0], error_70_f3.mean()[0], error_90_f3.mean()[0] ]
f3_knn_rmae  = [ error_orig_f3.mean()[1] , error_50_f3.mean()[1], error_70_f3.mean()[1], error_90_f3.mean()[1] ]
f3_kri_rmae  = [ error_orig_f3.mean()[2] , error_50_f3.mean()[2], error_70_f3.mean()[2], error_90_f3.mean()[2] ]
f3_svr_rmae  = [ error_orig_f3.mean()[3] , error_50_f3.mean()[3], error_70_f3.mean()[3], error_90_f3.mean()[3] ]

f7_poly_rmae  = [ error_orig_f7.mean()[0] , error_50_f7.mean()[0], error_70_f7.mean()[0], error_90_f7.mean()[0] ]
f7_knn_rmae  = [ error_orig_f7.mean()[1] , error_50_f7.mean()[1], error_70_f7.mean()[1], error_90_f7.mean()[1] ]
f7_kri_rmae  = [ error_orig_f7.mean()[2] , error_50_f7.mean()[2], error_70_f7.mean()[2], error_90_f7.mean()[2] ]
f7_svr_rmae  = [ error_orig_f7.mean()[3] , error_50_f7.mean()[3], error_70_f7.mean()[3], error_90_f7.mean()[3] ]

f9_poly_rmae  = [ error_orig_f9.mean()[0] , error_50_f9.mean()[0], error_70_f9.mean()[0], error_90_f9.mean()[0] ]
f9_knn_rmae  = [ error_orig_f9.mean()[1] , error_50_f9.mean()[1], error_70_f9.mean()[1], error_90_f9.mean()[1] ]
f9_kri_rmae  = [ error_orig_f9.mean()[2] , error_50_f9.mean()[2], error_70_f9.mean()[2], error_90_f9.mean()[2] ]
f9_svr_rmae  = [ error_orig_f9.mean()[3] , error_50_f9.mean()[3], error_70_f9.mean()[3], error_90_f9.mean()[3] ]

f10_poly_rmae  = [ error_orig_f10.mean()[0] , error_50_f10.mean()[0], error_70_f10.mean()[0], error_90_f10.mean()[0] ]
f10_knn_rmae  = [ error_orig_f10.mean()[1] , error_50_f10.mean()[1], error_70_f10.mean()[1], error_90_f10.mean()[1] ]
f10_kri_rmae  = [ error_orig_f10.mean()[2] , error_50_f10.mean()[2], error_70_f10.mean()[2], error_90_f10.mean()[2] ]
f10_svr_rmae  = [ error_orig_f10.mean()[3] , error_50_f10.mean()[3], error_70_f10.mean()[3], error_90_f10.mean()[3] ]

f13_poly_rmae  = [ error_orig_f13.mean()[0] , error_50_f13.mean()[0], error_70_f13.mean()[0], error_90_f13.mean()[0] ]
f13_knn_rmae  = [ error_orig_f13.mean()[1] , error_50_f13.mean()[1], error_70_f13.mean()[1], error_90_f13.mean()[1] ]
f13_kri_rmae  = [ error_orig_f13.mean()[2] , error_50_f13.mean()[2], error_70_f13.mean()[2], error_90_f13.mean()[2] ]
f13_svr_rmae  = [ error_orig_f13.mean()[3] , error_50_f13.mean()[3], error_70_f13.mean()[3], error_90_f13.mean()[3] ]

f15_poly_rmae  = [ error_orig_f15.mean()[0] , error_50_f15.mean()[0], error_70_f15.mean()[0], error_90_f15.mean()[0] ]
f15_knn_rmae  = [ error_orig_f15.mean()[1] , error_50_f15.mean()[1], error_70_f15.mean()[1], error_90_f15.mean()[1] ]
f15_kri_rmae  = [ error_orig_f15.mean()[2] , error_50_f15.mean()[2], error_70_f15.mean()[2], error_90_f15.mean()[2] ]
f15_svr_rmae  = [ error_orig_f15.mean()[3] , error_50_f15.mean()[3], error_70_f15.mean()[3], error_90_f15.mean()[3] ]

f16_poly_rmae  = [ error_orig_f16.mean()[0] , error_50_f16.mean()[0], error_70_f16.mean()[0], error_90_f16.mean()[0] ]
f16_knn_rmae  = [ error_orig_f16.mean()[1] , error_50_f16.mean()[1], error_70_f16.mean()[1], error_90_f16.mean()[1] ]
f16_kri_rmae  = [ error_orig_f16.mean()[2] , error_50_f16.mean()[2], error_70_f16.mean()[2], error_90_f16.mean()[2] ]
f16_svr_rmae  = [ error_orig_f16.mean()[3] , error_50_f16.mean()[3], error_70_f16.mean()[3], error_90_f16.mean()[3] ]

f20_poly_rmae  = [ error_orig_f20.mean()[0] , error_50_f20.mean()[0], error_70_f20.mean()[0], error_90_f20.mean()[0] ]
f20_knn_rmae  = [ error_orig_f20.mean()[1] , error_50_f20.mean()[1], error_70_f20.mean()[1], error_90_f20.mean()[1] ]
f20_kri_rmae  = [ error_orig_f20.mean()[2] , error_50_f20.mean()[2], error_70_f20.mean()[2], error_90_f20.mean()[2] ]
f20_svr_rmae  = [ error_orig_f20.mean()[3] , error_50_f20.mean()[3], error_70_f20.mean()[3], error_90_f20.mean()[3] ]

f24_poly_rmae  = [ error_orig_f24.mean()[0] , error_50_f24.mean()[0],  error_70_f24.mean()[0], error_90_f24.mean()[0] ]
f24_knn_rmae  = [ error_orig_f24.mean()[1] , error_50_f24.mean()[1],  error_70_f24.mean()[1], error_90_f24.mean()[1] ]
f24_kri_rmae  = [ error_orig_f24.mean()[2] , error_50_f24.mean()[2],  error_70_f24.mean()[2], error_90_f24.mean()[2] ]
f24_svr_rmae  = [ error_orig_f24.mean()[3] , error_50_f24.mean()[3], error_70_f24.mean()[3], error_90_f24.mean()[3] ]


f2_poly_std  = [ error_orig_f2.std()[0] , error_50_f2.std()[0], error_70_f2.std()[0], error_90_f2.std()[0] ]
f2_knn_std  = [ error_orig_f2.std()[1] , error_50_f2.std()[1], error_70_f2.std()[1], error_90_f2.std()[1] ]
f2_kri_std  = [ error_orig_f2.std()[2] , error_50_f2.std()[2], error_70_f2.std()[2], error_90_f2.std()[2] ]
f2_svr_std  = [ error_orig_f2.std()[3] , error_50_f2.std()[3], error_70_f2.std()[3], error_90_f2.std()[3] ]

f3_poly_std  = [ error_orig_f3.std()[0] , error_50_f3.std()[0], error_70_f3.std()[0], error_90_f3.std()[0] ]
f3_knn_std  = [ error_orig_f3.std()[1] , error_50_f3.std()[1], error_70_f3.std()[1], error_90_f3.std()[1] ]
f3_kri_std  = [ error_orig_f3.std()[2] , error_50_f3.std()[2], error_70_f3.std()[2], error_90_f3.std()[2] ]
f3_svr_std  = [ error_orig_f3.std()[3] , error_50_f3.std()[3], error_70_f3.std()[3], error_90_f3.std()[3] ]

f7_poly_std  = [ error_orig_f7.std()[0] , error_50_f7.std()[0], error_70_f7.std()[0], error_90_f7.std()[0] ]
f7_knn_std  = [ error_orig_f7.std()[1] , error_50_f7.std()[1], error_70_f7.std()[1], error_90_f7.std()[1] ]
f7_kri_std  = [ error_orig_f7.std()[2] , error_50_f7.std()[2], error_70_f7.std()[2], error_90_f7.std()[2] ]
f7_svr_std  = [ error_orig_f7.std()[3] , error_50_f7.std()[3], error_70_f7.std()[3], error_90_f7.std()[3] ]

f9_poly_std  = [ error_orig_f9.std()[0] , error_50_f9.std()[0], error_70_f9.std()[0], error_90_f9.std()[0] ]
f9_knn_std  = [ error_orig_f9.std()[1] , error_50_f9.std()[1], error_70_f9.std()[1], error_90_f9.std()[1] ]
f9_kri_std  = [ error_orig_f9.std()[2] , error_50_f9.std()[2], error_70_f9.std()[2], error_90_f9.std()[2] ]
f9_svr_std  = [ error_orig_f9.std()[3] , error_50_f9.std()[3], error_70_f9.std()[3], error_90_f9.std()[3] ]

f10_poly_std  = [ error_orig_f10.std()[0] , error_50_f10.std()[0], error_70_f10.std()[0], error_90_f10.std()[0] ]
f10_knn_std  = [ error_orig_f10.std()[1] , error_50_f10.std()[1], error_70_f10.std()[1], error_90_f10.std()[1] ]
f10_kri_std  = [ error_orig_f10.std()[2] , error_50_f10.std()[2], error_70_f10.std()[2], error_90_f10.std()[2] ]
f10_svr_std  = [ error_orig_f10.std()[3] , error_50_f10.std()[3], error_70_f10.std()[3], error_90_f10.std()[3] ]

f13_poly_std  = [ error_orig_f13.std()[0] , error_50_f13.std()[0], error_70_f13.std()[0], error_90_f13.std()[0] ]
f13_knn_std  = [ error_orig_f13.std()[1] , error_50_f13.std()[1], error_70_f13.std()[1], error_90_f13.std()[1] ]
f13_kri_std  = [ error_orig_f13.std()[2] , error_50_f13.std()[2], error_70_f13.std()[2], error_90_f13.std()[2] ]
f13_svr_std  = [ error_orig_f13.std()[3] , error_50_f13.std()[3], error_70_f13.std()[3], error_90_f13.std()[3] ]

f15_poly_std  = [ error_orig_f15.std()[0] , error_50_f15.std()[0], error_70_f15.std()[0], error_90_f15.std()[0] ]
f15_knn_std  = [ error_orig_f15.std()[1] , error_50_f15.std()[1], error_70_f15.std()[1], error_90_f15.std()[1] ]
f15_kri_std  = [ error_orig_f15.std()[2] , error_50_f15.std()[2], error_70_f15.std()[2], error_90_f15.std()[2] ]
f15_svr_std  = [ error_orig_f15.std()[3] , error_50_f15.std()[3], error_70_f15.std()[3], error_90_f15.std()[3] ]

f16_poly_std  = [ error_orig_f16.std()[0] , error_50_f16.std()[0], error_70_f16.std()[0], error_90_f16.std()[0] ]
f16_knn_std  = [ error_orig_f16.std()[1] , error_50_f16.std()[1], error_70_f16.std()[1], error_90_f16.std()[1] ]
f16_kri_std  = [ error_orig_f16.std()[2] , error_50_f16.std()[2], error_70_f16.std()[2], error_90_f16.std()[2] ]
f16_svr_std  = [ error_orig_f16.std()[3] , error_50_f16.std()[3], error_70_f16.std()[3], error_90_f16.std()[3] ]

f20_poly_std  = [ error_orig_f20.std()[0] , error_50_f20.std()[0], error_70_f20.std()[0], error_90_f20.std()[0] ]
f20_knn_std  = [ error_orig_f20.std()[1] , error_50_f20.std()[1], error_70_f20.std()[1], error_90_f20.std()[1] ]
f20_kri_std  = [ error_orig_f20.std()[2] , error_50_f20.std()[2], error_70_f20.std()[2], error_90_f20.std()[2] ]
f20_svr_std  = [ error_orig_f20.std()[3] , error_50_f20.std()[3], error_70_f20.std()[3], error_90_f20.std()[3] ]

f24_poly_std  = [ error_orig_f24.std()[0] , error_50_f24.std()[0],  error_70_f24.std()[0], error_90_f24.std()[0] ]
f24_knn_std  = [ error_orig_f24.std()[1] , error_50_f24.std()[1],  error_70_f24.std()[1], error_90_f24.std()[1] ]
f24_kri_std  = [ error_orig_f24.std()[2] , error_50_f24.std()[2],  error_70_f24.std()[2], error_90_f24.std()[2] ]
f24_svr_std  = [ error_orig_f24.std()[3] , error_50_f24.std()[3], error_70_f24.std()[3], error_90_f24.std()[3] ]

f2_poly_time  = [ 2.32, 0.665 , 0.121 , 0.0187]
#f2_knn_time  = [ 0.00821 , 0.008 , 0.01 , 0.00735]
f2_kri_time  = [ 60, 37 , 25 , 19.4]
f2_svr_time  = [ 1.63 , 0.381 , 0.545 , 0.166]

f3_poly_time  = [ 4.18 , 0.264 , 0.132 , 0.0234 ]
#f3_knn_time  = [ 0.0185 , 0.008 , 0.0079 , 0.0083 ]
f3_kri_time  = [ 60 , 38, 34 , 19 ]
f3_svr_time  = [ 1.65 , 0.389 , 0.273 , 0.172 ]

f7_poly_time  = [ 3.36 , 0.262 , 0.098, 0.017 ]
#f7_knn_time  = [ 0.0201 , 0.0082 , 0.0078 , 0.0083 ]
f7_kri_time  = [ 61 , 42 , 34 ,  29]
f7_svr_time  = [ 1.66 , 0.376 , 0.273 , 0.167 ]

f9_poly_time  = [ 1.92 , 0.249 , 0.095 , 0.019 ]
#f9_knn_time  = [ 0.0254 , 0.0089 , 0.0077 , 0.0091 ]
f9_kri_time  = [ 55 , 37 , 33.3 , 25 ]
f9_svr_time  = [ 1.67 , 0.382 , 0.272 , 0.168 ]

f10_poly_time  = [ 53 , 0.232 , 0.101 , 0.022 ]
#f10_knn_time  = [ 0.0189 , 0.0079 , 0.0088 , 0.0085 ]
f10_kri_time  = [ 59 , 28 ,28 ,21 ]
f10_svr_time  = [ 1.63 , 0.384 , 0.544 ,0.169 ]

f13_poly_time  = [  11.3, 0.274 , 0.098 , 0.021]
#f13_knn_time  = [ 0.0208 , 0.00775 , 0.0076 , 0.008 ]
f13_kri_time  = [ 74 , 38 , 33.3 , 31 ]
f13_svr_time  = [ 1.55 , 0.375 , 0.458 , 0.223 ]

f15_poly_time  = [ 2.11 , 0.261 , 0.099 , 0.021 ]
#f15_knn_time  = [ 0.0189 , 0.008 , 0.0076 , 0.0088]
f15_kri_time  = [ 87 , 37 , 33.8 , 26  ]
f15_svr_time  = [ 1.66 , 0.392 , 0.475 , 0.166 ]

f16_poly_time  = [ 1.58 , 0.231 , 0.086 , 0.017 ]
#f16_knn_time  = [ 0.0246 , 0.022 , 0.013 , 0.019 ]
f16_kri_time  = [ 37 , 28 , 18 , 12 ]
f16_svr_time  = [ 2 , 0.362 , 0.260 , 0.164 ]

f20_poly_time  = [ 4.6 , 0.266 , 0.116 , 0.024 ]
#f20_knn_time  = [ 0.0182 , 0.008 , 0.0071 , 0.0086 ]
f20_kri_time  = [ 62 , 37 , 35, 23 ]
f20_svr_time  = [ 1.6 , 0.383 , 0.346 , 0.170 ]

f24_poly_time  = [10.6 , 0.290 , 0.110 , 0.320 ]
#f24_knn_time  = [ 0.0632 , 0.027 , 0.0074 , 0.0085 ]
f24_kri_time  = [ 54 , 38 , 36 , 22 ]
f24_svr_time  = [1.54, 0.369 , 0.271 , 0.166 ]

# %%
cols = ['Noise Level : 5 %','Noise Level : 10 %','Noise Level : 20 %']
rows = ['F(2,3,7,9,10)','F(13,15,16,20,24)']

f, axarr = plt.subplots(2, 5,figsize=(15,6))


line = []
line.append(axarr[0,0].errorbar(f2_poly_rmae , f2_poly_time  , marker='v', 
                     color='r',label='ELN', fillstyle='none',markersize=8)[0])
line.append(axarr[0,0].errorbar(f2_kri_rmae, f2_kri_time,  marker='s', 
                     color='b',label='Kriging',fillstyle='none',markersize=8)[0])
line.append(axarr[0,0].errorbar(f2_svr_rmae , f2_svr_time,   marker='*', 
                     color='g',label='SVR',fillstyle='none',markersize=8)[0])

axarr[0,0].set_yscale('log',basey=2)
axarr[0,0].set_xscale('log',basex=2)
axarr[0,0].set_ylabel('Time (Seconds)',size=12)
axarr[0,0].grid(which='major')
axarr[0,0].set_title('F2')
axarr[0,0].tick_params(labelsize=12)

axarr[0,1].errorbar( f3_poly_rmae, f3_poly_time , marker='v' ,  color='r', fillstyle='none',markersize=8)
axarr[0,1].errorbar(f3_poly_rmae , f3_kri_time,  marker='s' , color='b', fillstyle='none',markersize=8)
axarr[0,1].errorbar(f3_poly_rmae , f3_svr_time, marker='*' , color='g', fillstyle='none',markersize=8)

axarr[0,1].set_yscale('log',basey=2)
axarr[0,1].set_xscale('log',basex=2)
axarr[0,1].grid(which='major')
axarr[0,1].set_title('F3')
axarr[0,1].tick_params(labelsize=12)

axarr[0,2].errorbar(f7_poly_rmae , f7_poly_time , marker='v' ,  color='r', fillstyle='none',markersize=8)
axarr[0,2].errorbar(f7_poly_rmae , f7_kri_time,  marker='s' , color='b', fillstyle='none',markersize=8)
axarr[0,2].errorbar(f7_poly_rmae , f7_svr_time,  marker='*' , color='g', fillstyle='none',markersize=8)

axarr[0,2].set_yscale('log',basey=2)
axarr[0,2].set_xscale('log',basex=2)
axarr[0,2].grid(which='major')
axarr[0,2].set_title('F7')
axarr[0,2].tick_params(labelsize=12)

axarr[0,3].errorbar(f9_poly_rmae , f9_poly_time, marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[0,3].errorbar(f9_poly_rmae , f9_kri_time,  marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[0,3].errorbar(f9_poly_rmae, f9_svr_time,   marker='*' , color='g', fillstyle='none',markersize=8)

axarr[0,3].set_yscale('log',basey=2)
axarr[0,3].set_xscale('log',basex=2)
axarr[0,3].grid(which='major')
axarr[0,3].set_title('F9')
axarr[0,3].tick_params(labelsize=12)


axarr[0,4].errorbar(f10_poly_rmae, f10_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[0,4].errorbar(f10_poly_rmae , f10_kri_time,  marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[0,4].errorbar(f10_poly_rmae, f10_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[0,4].set_yscale('log',basey=2)
axarr[0,4].set_xscale('log',basex=2)
axarr[0,4].grid(which='major')
axarr[0,4].set_title('F10')
axarr[0,4].tick_params(labelsize=12)

axarr[1,0].errorbar(f13_poly_rmae, f13_poly_time,   marker='v' ,  color='r', fillstyle='none',markersize=8)
axarr[1,0].errorbar(f13_poly_rmae, f13_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,0].errorbar(f13_poly_rmae, f13_svr_time, marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,0].set_xlabel('RMAE (%)',size=12)
axarr[1,0].set_yscale('log',basey=2)
axarr[1,0].set_xscale('log',basex=2)
axarr[1,0].set_ylabel('Time (Seconds)',size=12)
axarr[1,0].grid(which='major')
axarr[1,0].set_title('F13')
axarr[1,0].tick_params(labelsize=12)

axarr[1,1].errorbar(f15_poly_rmae, f15_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,1].errorbar(f15_poly_rmae, f15_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,1].errorbar(f15_poly_rmae, f15_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,1].set_xlabel('RMAE (%)',size=12)
axarr[1,1].set_yscale('log',basey=2)
axarr[1,1].set_xscale('log',basex=2)
axarr[1,1].grid(which='major')
axarr[1,1].set_title('F15')
axarr[1,1].tick_params(labelsize=12)

axarr[1,2].errorbar(f16_poly_rmae, f16_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,2].errorbar(f16_poly_rmae, f16_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,2].errorbar(f16_poly_rmae,f16_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,2].set_xlabel('RMAE (%)',size=12)
axarr[1,2].set_yscale('log',basey=2)
axarr[1,2].set_xscale('log',basex=2)
axarr[1,2].grid(which='major')
axarr[1,2].set_title('F16')
axarr[1,2].tick_params(labelsize=12)

axarr[1,3].errorbar(f20_poly_rmae, f20_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,3].errorbar(f20_poly_rmae, f20_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,3].errorbar(f20_poly_rmae, f20_svr_time,   marker='*' , color='g', fillstyle='none',markersize=8)

axarr[1,3].set_xlabel('RMAE (%)',size=12)
axarr[1,3].set_yscale('log',basey=2)
axarr[1,3].set_xscale('log',basex=2)
axarr[1,3].grid(which='major')
axarr[1,3].set_title('F20')
axarr[1,3].tick_params(labelsize=12)

axarr[1,4].errorbar(f24_poly_rmae, f24_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,4].errorbar(f24_poly_rmae, f24_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,4].errorbar(f24_poly_rmae, f24_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,4].set_xlabel('RMAE (%)',size=12)
axarr[1,4].set_yscale('log',basey=2)
axarr[1,4].set_xscale('log',basex=2)
axarr[1,4].grid(which='major')
axarr[1,4].set_title('F24')
axarr[1,4].tick_params(labelsize=12)

pad = 10

f.tight_layout()   
plt.show()
f.savefig("100 D.pdf",bbox_inches='tight')

# %% [markdown]
# ## 200 D

# %%
orig_path = "Surrogate Modeling\\Original\\Modeling Accuracy\\200 D\\Results\\"
orig_f2 = pd.read_csv(orig_path+'F2_Accuracy.csv', index_col=0)
orig_f3 = pd.read_csv(orig_path+'F3_Accuracy.csv', index_col=0)
orig_f7 = pd.read_csv(orig_path+'F7_Accuracy.csv', index_col=0)
orig_f9 = pd.read_csv(orig_path+'F9_Accuracy.csv', index_col=0)
orig_f10 = pd.read_csv(orig_path+'F10_Accuracy.csv', index_col=0)
orig_f13 = pd.read_csv(orig_path+'F13_Accuracy.csv', index_col=0)
orig_f15 = pd.read_csv(orig_path+'F15_Accuracy.csv', index_col=0)
orig_f16 = pd.read_csv(orig_path+'F16_Accuracy.csv', index_col=0)
orig_f20 = pd.read_csv(orig_path+'F20_Accuracy.csv', index_col=0)
orig_f24 = pd.read_csv(orig_path+'F24_Accuracy.csv', index_col=0)

lat_50_path = "Surrogate Modeling\\Latent\\Modeling Accuracy\\50 %\\200 D\\Results\\"
lat_50_f2 = pd.read_csv(lat_50_path+'F2_Accuracy.csv', index_col=0)
lat_50_f3 = pd.read_csv(lat_50_path+'F3_Accuracy.csv', index_col=0)
lat_50_f7 = pd.read_csv(lat_50_path+'F7_Accuracy.csv', index_col=0)
lat_50_f9 = pd.read_csv(lat_50_path+'F9_Accuracy.csv', index_col=0)
lat_50_f10 = pd.read_csv(lat_50_path+'F10_Accuracy.csv', index_col=0)
lat_50_f13 = pd.read_csv(lat_50_path+'F13_Accuracy.csv', index_col=0)
lat_50_f15 = pd.read_csv(lat_50_path+'F15_Accuracy.csv', index_col=0)
lat_50_f16 = pd.read_csv(lat_50_path+'F16_Accuracy.csv', index_col=0)
lat_50_f20 = pd.read_csv(lat_50_path+'F20_Accuracy.csv', index_col=0)
lat_50_f24 = pd.read_csv(lat_50_path+'F24_Accuracy.csv', index_col=0)



lat_70_path = "Surrogate Modeling\\Latent\\Modeling Accuracy\\70 %\\200 D\\Results\\"
lat_70_f2 = pd.read_csv(lat_70_path+'F2_Accuracy.csv', index_col=0)
lat_70_f3 = pd.read_csv(lat_70_path+'F3_Accuracy.csv', index_col=0)
lat_70_f7 = pd.read_csv(lat_70_path+'F7_Accuracy.csv', index_col=0)
lat_70_f9 = pd.read_csv(lat_70_path+'F9_Accuracy.csv', index_col=0)
lat_70_f10 = pd.read_csv(lat_70_path+'F10_Accuracy.csv', index_col=0)
lat_70_f13 = pd.read_csv(lat_70_path+'F13_Accuracy.csv', index_col=0)
lat_70_f15 = pd.read_csv(lat_70_path+'F15_Accuracy.csv', index_col=0)
lat_70_f16 = pd.read_csv(lat_70_path+'F16_Accuracy.csv', index_col=0)
lat_70_f20 = pd.read_csv(lat_70_path+'F20_Accuracy.csv', index_col=0)
lat_70_f24 = pd.read_csv(lat_70_path+'F24_Accuracy.csv', index_col=0)


lat_90_path = "Surrogate Modeling\\Latent\\Modeling Accuracy\\90 %\\200 D\\Results\\"
lat_90_f2 = pd.read_csv(lat_90_path+'F2_Accuracy.csv', index_col=0)
lat_90_f3 = pd.read_csv(lat_90_path+'F3_Accuracy.csv', index_col=0)
lat_90_f7 = pd.read_csv(lat_90_path+'F7_Accuracy.csv', index_col=0)
lat_90_f9 = pd.read_csv(lat_90_path+'F9_Accuracy.csv', index_col=0)
lat_90_f10 = pd.read_csv(lat_90_path+'F10_Accuracy.csv', index_col=0)
lat_90_f13 = pd.read_csv(lat_90_path+'F13_Accuracy.csv', index_col=0)
lat_90_f15 = pd.read_csv(lat_90_path+'F15_Accuracy.csv', index_col=0)
lat_90_f16 = pd.read_csv(lat_90_path+'F16_Accuracy.csv', index_col=0)
lat_90_f20 = pd.read_csv(lat_90_path+'F20_Accuracy.csv', index_col=0)
lat_90_f24 = pd.read_csv(lat_90_path+'F24_Accuracy.csv', index_col=0)

# %%
error_orig_f2 = pd.DataFrame(data= [(abs(orig_f2['True']-orig_f2['ELN'])/abs(orig_f2['True'])) * 100 , 
                   (abs(orig_f2['True']-orig_f2['KNN'])/abs(orig_f2['True'])) * 100, 
                   (abs(orig_f2['True']-orig_f2['Kri'])/abs(orig_f2['True'])) * 100,
                    (abs(orig_f2['True']-orig_f2['SVR'])/abs(orig_f2['True'])) * 100]).T
error_orig_f2.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']


error_orig_f3 = pd.DataFrame(data= [(abs(orig_f3['True']-orig_f3['ELN'])/abs(orig_f3['True'])) * 100 , 
                   (abs(orig_f3['True']-orig_f3['KNN'])/abs(orig_f3['True'])) * 100, 
                   (abs(orig_f3['True']-orig_f3['Kri'])/abs(orig_f3['True'])) * 100,
                    (abs(orig_f3['True']-orig_f3['SVR'])/abs(orig_f3['True'])) * 100]).T
error_orig_f3.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f7 = pd.DataFrame(data= [(abs(orig_f7['True']-orig_f7['ELN'])/abs(orig_f7['True'])) * 100 , 
                   (abs(orig_f7['True']-orig_f7['KNN'])/abs(orig_f7['True'])) * 100, 
                   (abs(orig_f7['True']-orig_f7['Kri'])/abs(orig_f7['True'])) * 100,
                    (abs(orig_f7['True']-orig_f7['SVR'])/abs(orig_f7['True'])) * 100]).T
error_orig_f7.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f9 = pd.DataFrame(data= [(abs(orig_f9['True']-orig_f9['ELN'])/abs(orig_f9['True'])) * 100 , 
                   (abs(orig_f9['True']-orig_f9['KNN'])/abs(orig_f9['True'])) * 100, 
                   (abs(orig_f9['True']-orig_f9['Kri'])/abs(orig_f9['True'])) * 100,
                    (abs(orig_f9['True']-orig_f9['SVR'])/abs(orig_f9['True'])) * 100]).T
error_orig_f9.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f10 = pd.DataFrame(data= [(abs(orig_f10['True']-orig_f10['ELN'])/abs(orig_f10['True'])) * 100 , 
                   (abs(orig_f10['True']-orig_f10['KNN'])/abs(orig_f10['True'])) * 100, 
                   (abs(orig_f10['True']-orig_f10['Kri'])/abs(orig_f10['True'])) * 100,
                    (abs(orig_f10['True']-orig_f10['SVR'])/abs(orig_f10['True'])) * 100]).T
error_orig_f10.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f13 = pd.DataFrame(data= [(abs(orig_f13['True']-orig_f13['ELN'])/abs(orig_f13['True'])) * 100 , 
                   (abs(orig_f13['True']-orig_f13['KNN'])/abs(orig_f13['True'])) * 100, 
                   (abs(orig_f13['True']-orig_f13['Kri'])/abs(orig_f13['True'])) * 100,
                    (abs(orig_f13['True']-orig_f13['SVR'])/abs(orig_f13['True'])) * 100]).T
error_orig_f13.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f15 = pd.DataFrame(data= [(abs(orig_f15['True']-orig_f15['ELN'])/abs(orig_f15['True'])) * 100 , 
                   (abs(orig_f15['True']-orig_f15['KNN'])/abs(orig_f15['True'])) * 100, 
                   (abs(orig_f15['True']-orig_f15['Kri'])/abs(orig_f15['True'])) * 100,
                    (abs(orig_f15['True']-orig_f15['SVR'])/abs(orig_f15['True'])) * 100]).T
error_orig_f15.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f16 = pd.DataFrame(data= [(abs(orig_f16['True']-orig_f16['ELN'])/abs(orig_f16['True'])) * 100 , 
                   (abs(orig_f16['True']-orig_f16['KNN'])/abs(orig_f16['True'])) * 100, 
                   (abs(orig_f16['True']-orig_f16['Kri'])/abs(orig_f16['True'])) * 100,
                    (abs(orig_f16['True']-orig_f16['SVR'])/abs(orig_f16['True'])) * 100]).T
error_orig_f16.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f20 = pd.DataFrame(data= [(abs(orig_f20['True']-orig_f20['ELN'])/abs(orig_f20['True'])) * 100 , 
                   (abs(orig_f20['True']-orig_f20['KNN'])/abs(orig_f20['True'])) * 100, 
                   (abs(orig_f20['True']-orig_f20['Kri'])/abs(orig_f20['True'])) * 100,
                    (abs(orig_f20['True']-orig_f20['SVR'])/abs(orig_f20['True'])) * 100]).T
error_orig_f20.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_orig_f24 = pd.DataFrame(data= [(abs(orig_f24['True']-orig_f24['ELN'])/abs(orig_f20['True'])) * 100 , 
                   (abs(orig_f24['True']-orig_f24['KNN'])/abs(orig_f24['True'])) * 100, 
                   (abs(orig_f24['True']-orig_f24['Kri'])/abs(orig_f24['True'])) * 100,
                    (abs(orig_f24['True']-orig_f24['SVR'])/abs(orig_f24['True'])) * 100]).T
error_orig_f24.columns = ['Orig_ELN','Orig_KNN','Orig_Kri','Orig_SVR']

error_50_f2 = pd.DataFrame(data= [(abs(lat_50_f2['True']-lat_50_f2['ELN'])/abs(lat_50_f2['True'])) * 100 , 
                   (abs(lat_50_f2['True']-lat_50_f2['KNN'])/abs(lat_50_f2['True'])) * 100, 
                   (abs(lat_50_f2['True']-lat_50_f2['Kri'])/abs(lat_50_f2['True'])) * 100,
                    (abs(lat_50_f2['True']-lat_50_f2['SVR'])/abs(lat_50_f2['True'])) * 100]).T
error_50_f2.columns = ['ELN','KNN','Kri','SVR']

error_50_f3 = pd.DataFrame(data= [(abs(lat_50_f3['True']-lat_50_f3['ELN'])/abs(lat_50_f3['True'])) * 100 , 
                   (abs(lat_50_f3['True']-lat_50_f3['KNN'])/abs(lat_50_f3['True'])) * 100, 
                   (abs(lat_50_f3['True']-lat_50_f3['Kri'])/abs(lat_50_f3['True'])) * 100,
                    (abs(lat_50_f3['True']-lat_50_f3['SVR'])/abs(lat_50_f3['True'])) * 100]).T
error_50_f3.columns = ['ELN','KNN','Kri','SVR']

error_50_f7 = pd.DataFrame(data= [(abs(lat_50_f7['True']-lat_50_f7['ELN'])/abs(lat_50_f7['True'])) * 100 , 
                   (abs(lat_50_f7['True']-lat_50_f7['KNN'])/abs(lat_50_f7['True'])) * 100, 
                   (abs(lat_50_f7['True']-lat_50_f7['Kri'])/abs(lat_50_f7['True'])) * 100,
                    (abs(lat_50_f7['True']-lat_50_f7['SVR'])/abs(lat_50_f7['True'])) * 100]).T
error_50_f7.columns = ['ELN','KNN','Kri','SVR']

error_50_f9 = pd.DataFrame(data= [(abs(lat_50_f9['True']-lat_50_f9['ELN'])/abs(lat_50_f9['True'])) * 100 , 
                   (abs(lat_50_f9['True']-lat_50_f9['KNN'])/abs(lat_50_f9['True'])) * 100, 
                   (abs(lat_50_f9['True']-lat_50_f9['Kri'])/abs(lat_50_f9['True'])) * 100,
                    (abs(lat_50_f9['True']-lat_50_f9['SVR'])/abs(lat_50_f9['True'])) * 100]).T
error_50_f9.columns = ['ELN','KNN','Kri','SVR']

error_50_f10 = pd.DataFrame(data= [(abs(lat_50_f10['True']-lat_50_f10['ELN'])/abs(lat_50_f10['True'])) * 100 , 
                   (abs(lat_50_f10['True']-lat_50_f10['KNN'])/abs(lat_50_f10['True'])) * 100, 
                   (abs(lat_50_f10['True']-lat_50_f10['Kri'])/abs(lat_50_f10['True'])) * 100,
                    (abs(lat_50_f10['True']-lat_50_f10['SVR'])/abs(lat_50_f10['True'])) * 100]).T
error_50_f10.columns = ['ELN','KNN','Kri','SVR']

error_50_f13 = pd.DataFrame(data= [(abs(lat_50_f13['True']-lat_50_f13['ELN'])/abs(lat_50_f13['True'])) * 100 , 
                   (abs(lat_50_f13['True']-lat_50_f13['KNN'])/abs(lat_50_f13['True'])) * 100, 
                   (abs(lat_50_f13['True']-lat_50_f13['Kri'])/abs(lat_50_f13['True'])) * 100,
                    (abs(lat_50_f13['True']-lat_50_f13['SVR'])/abs(lat_50_f13['True'])) * 100]).T
error_50_f13.columns = ['ELN','KNN','Kri','SVR']

error_50_f15 = pd.DataFrame(data= [(abs(lat_50_f15['True']-lat_50_f15['ELN'])/abs(lat_50_f15['True'])) * 100 , 
                   (abs(lat_50_f15['True']-lat_50_f15['KNN'])/abs(lat_50_f15['True'])) * 100, 
                   (abs(lat_50_f15['True']-lat_50_f15['Kri'])/abs(lat_50_f15['True'])) * 100,
                    (abs(lat_50_f15['True']-lat_50_f15['SVR'])/abs(lat_50_f15['True'])) * 100]).T
error_50_f15.columns = ['ELN','KNN','Kri','SVR']

error_50_f16 = pd.DataFrame(data= [(abs(lat_50_f16['True']-lat_50_f16['ELN'])/abs(lat_50_f16['True'])) * 100 , 
                   (abs(lat_50_f16['True']-lat_50_f16['KNN'])/abs(lat_50_f16['True'])) * 100, 
                   (abs(lat_50_f16['True']-lat_50_f16['Kri'])/abs(lat_50_f16['True'])) * 100,
                    (abs(lat_50_f16['True']-lat_50_f16['SVR'])/abs(lat_50_f16['True'])) * 100]).T
error_50_f16.columns = ['ELN','KNN','Kri','SVR']

error_50_f20 = pd.DataFrame(data= [(abs(lat_50_f20['True']-lat_50_f20['ELN'])/abs(lat_50_f20['True'])) * 100 , 
                   (abs(lat_50_f20['True']-lat_50_f20['KNN'])/abs(lat_50_f20['True'])) * 100, 
                   (abs(lat_50_f20['True']-lat_50_f20['Kri'])/abs(lat_50_f20['True'])) * 100,
                    (abs(lat_50_f20['True']-lat_50_f20['SVR'])/abs(lat_50_f20['True'])) * 100]).T
error_50_f20.columns = ['ELN','KNN','Kri','SVR']

error_50_f24 = pd.DataFrame(data= [(abs(lat_50_f24['True']-lat_50_f24['ELN'])/abs(lat_50_f24['True'])) * 100 , 
                   (abs(lat_50_f24['True']-lat_50_f24['KNN'])/abs(lat_50_f24['True'])) * 100, 
                   (abs(lat_50_f24['True']-lat_50_f24['Kri'])/abs(lat_50_f24['True'])) * 100,
                    (abs(lat_50_f24['True']-lat_50_f24['SVR'])/abs(lat_50_f24['True'])) * 100]).T
error_50_f24.columns = ['ELN','KNN','Kri','SVR']


error_70_f2 = pd.DataFrame(data= [(abs(lat_70_f2['True']-lat_70_f2['ELN'])/abs(lat_70_f2['True'])) * 100 , 
                   (abs(lat_70_f2['True']-lat_70_f2['KNN'])/abs(lat_70_f2['True'])) * 100, 
                   (abs(lat_70_f2['True']-lat_70_f2['Kri'])/abs(lat_70_f2['True'])) * 100,
                    (abs(lat_70_f2['True']-lat_70_f2['SVR'])/abs(lat_70_f2['True'])) * 100]).T
error_70_f2.columns = ['ELN','KNN','Kri','SVR']

error_70_f3 = pd.DataFrame(data= [(abs(lat_70_f3['True']-lat_70_f3['ELN'])/abs(lat_70_f3['True'])) * 100 , 
                   (abs(lat_70_f3['True']-lat_70_f3['KNN'])/abs(lat_70_f3['True'])) * 100, 
                   (abs(lat_70_f3['True']-lat_70_f3['Kri'])/abs(lat_70_f3['True'])) * 100,
                    (abs(lat_70_f3['True']-lat_70_f3['SVR'])/abs(lat_70_f3['True'])) * 100]).T
error_70_f3.columns = ['ELN','KNN','Kri','SVR']

error_70_f7 = pd.DataFrame(data= [(abs(lat_70_f7['True']-lat_70_f7['ELN'])/abs(lat_70_f7['True'])) * 100 , 
                   (abs(lat_70_f7['True']-lat_70_f7['KNN'])/abs(lat_70_f7['True'])) * 100, 
                   (abs(lat_70_f7['True']-lat_70_f7['Kri'])/abs(lat_70_f7['True'])) * 100,
                    (abs(lat_70_f7['True']-lat_70_f7['SVR'])/abs(lat_70_f7['True'])) * 100]).T
error_70_f7.columns = ['ELN','KNN','Kri','SVR']

error_70_f9 = pd.DataFrame(data= [(abs(lat_70_f9['True']-lat_70_f9['ELN'])/abs(lat_70_f9['True'])) * 100 , 
                   (abs(lat_70_f9['True']-lat_70_f9['KNN'])/abs(lat_70_f9['True'])) * 100, 
                   (abs(lat_70_f9['True']-lat_70_f9['Kri'])/abs(lat_70_f9['True'])) * 100,
                    (abs(lat_70_f9['True']-lat_70_f9['SVR'])/abs(lat_70_f9['True'])) * 100]).T
error_70_f9.columns = ['ELN','KNN','Kri','SVR']

error_70_f10 = pd.DataFrame(data= [(abs(lat_70_f10['True']-lat_70_f10['ELN'])/abs(lat_70_f10['True'])) * 100 , 
                   (abs(lat_70_f10['True']-lat_70_f10['KNN'])/abs(lat_70_f10['True'])) * 100, 
                   (abs(lat_70_f10['True']-lat_70_f10['Kri'])/abs(lat_70_f10['True'])) * 100,
                    (abs(lat_70_f10['True']-lat_70_f10['SVR'])/abs(lat_70_f10['True'])) * 100]).T
error_70_f10.columns = ['ELN','KNN','Kri','SVR']

error_70_f13 = pd.DataFrame(data= [(abs(lat_70_f13['True']-lat_70_f13['ELN'])/abs(lat_70_f13['True'])) * 100 , 
                   (abs(lat_70_f13['True']-lat_70_f13['KNN'])/abs(lat_70_f13['True'])) * 100, 
                   (abs(lat_70_f13['True']-lat_70_f13['Kri'])/abs(lat_70_f13['True'])) * 100,
                    (abs(lat_70_f13['True']-lat_70_f13['SVR'])/abs(lat_70_f13['True'])) * 100]).T
error_70_f13.columns = ['ELN','KNN','Kri','SVR']

error_70_f15 = pd.DataFrame(data= [(abs(lat_70_f15['True']-lat_70_f15['ELN'])/abs(lat_70_f15['True'])) * 100 , 
                   (abs(lat_70_f15['True']-lat_70_f15['KNN'])/abs(lat_70_f15['True'])) * 100, 
                   (abs(lat_70_f15['True']-lat_70_f15['Kri'])/abs(lat_70_f15['True'])) * 100,
                    (abs(lat_70_f15['True']-lat_70_f15['SVR'])/abs(lat_70_f15['True'])) * 100]).T
error_70_f15.columns = ['ELN','KNN','Kri','SVR']

error_70_f16 = pd.DataFrame(data= [(abs(lat_70_f16['True']-lat_70_f16['ELN'])/abs(lat_70_f16['True'])) * 100 , 
                   (abs(lat_70_f16['True']-lat_70_f16['KNN'])/abs(lat_70_f16['True'])) * 100, 
                   (abs(lat_70_f16['True']-lat_70_f16['Kri'])/abs(lat_70_f16['True'])) * 100,
                    (abs(lat_70_f16['True']-lat_70_f16['SVR'])/abs(lat_70_f16['True'])) * 100]).T
error_70_f16.columns = ['ELN','KNN','Kri','SVR']

error_70_f20 = pd.DataFrame(data= [(abs(lat_70_f20['True']-lat_70_f20['ELN'])/abs(lat_70_f20['True'])) * 100 , 
                   (abs(lat_70_f20['True']-lat_70_f20['KNN'])/abs(lat_70_f20['True'])) * 100, 
                   (abs(lat_70_f20['True']-lat_70_f20['Kri'])/abs(lat_70_f20['True'])) * 100,
                    (abs(lat_70_f20['True']-lat_70_f20['SVR'])/abs(lat_70_f20['True'])) * 100]).T
error_70_f20.columns = ['ELN','KNN','Kri','SVR']

error_70_f24 = pd.DataFrame(data= [(abs(lat_70_f24['True']-lat_70_f24['ELN'])/abs(lat_70_f24['True'])) * 100 , 
                   (abs(lat_70_f24['True']-lat_70_f24['KNN'])/abs(lat_70_f24['True'])) * 100, 
                   (abs(lat_70_f24['True']-lat_70_f24['Kri'])/abs(lat_70_f24['True'])) * 100,
                    (abs(lat_70_f24['True']-lat_70_f24['SVR'])/abs(lat_70_f24['True'])) * 100]).T
error_70_f24.columns = ['ELN','KNN','Kri','SVR']



error_90_f2 = pd.DataFrame(data= [(abs(lat_90_f2['True']-lat_90_f2['ELN'])/abs(lat_90_f2['True'])) * 100 , 
                   (abs(lat_90_f2['True']-lat_90_f2['KNN'])/abs(lat_90_f2['True'])) * 100, 
                   (abs(lat_90_f2['True']-lat_90_f2['Kri'])/abs(lat_90_f2['True'])) * 100,
                    (abs(lat_90_f2['True']-lat_90_f2['SVR'])/abs(lat_90_f2['True'])) * 100]).T
error_90_f2.columns = ['ELN','KNN','Kri','SVR']

error_90_f3 = pd.DataFrame(data= [(abs(lat_90_f3['True']-lat_90_f3['ELN'])/abs(lat_90_f3['True'])) * 100 , 
                   (abs(lat_90_f3['True']-lat_90_f3['KNN'])/abs(lat_90_f3['True'])) * 100, 
                   (abs(lat_90_f3['True']-lat_90_f3['Kri'])/abs(lat_90_f3['True'])) * 100,
                    (abs(lat_90_f3['True']-lat_90_f3['SVR'])/abs(lat_90_f3['True'])) * 100]).T
error_90_f3.columns = ['ELN','KNN','Kri','SVR']

error_90_f7 = pd.DataFrame(data= [(abs(lat_90_f7['True']-lat_90_f7['ELN'])/abs(lat_90_f7['True'])) * 100 , 
                   (abs(lat_90_f7['True']-lat_90_f7['KNN'])/abs(lat_90_f7['True'])) * 100, 
                   (abs(lat_90_f7['True']-lat_90_f7['Kri'])/abs(lat_90_f7['True'])) * 100,
                    (abs(lat_90_f7['True']-lat_90_f7['SVR'])/abs(lat_90_f7['True'])) * 100]).T
error_90_f7.columns = ['ELN','KNN','Kri','SVR']

error_90_f9 = pd.DataFrame(data= [(abs(lat_90_f9['True']-lat_90_f9['ELN'])/abs(lat_90_f9['True'])) * 100 , 
                   (abs(lat_90_f9['True']-lat_90_f9['KNN'])/abs(lat_90_f9['True'])) * 100, 
                   (abs(lat_90_f9['True']-lat_90_f9['Kri'])/abs(lat_90_f9['True'])) * 100,
                    (abs(lat_90_f9['True']-lat_90_f9['SVR'])/abs(lat_90_f9['True'])) * 100]).T
error_90_f9.columns = ['ELN','KNN','Kri','SVR']

error_90_f10 = pd.DataFrame(data= [(abs(lat_90_f10['True']-lat_90_f10['ELN'])/abs(lat_90_f10['True'])) * 100 , 
                   (abs(lat_90_f10['True']-lat_90_f10['KNN'])/abs(lat_90_f10['True'])) * 100, 
                   (abs(lat_90_f10['True']-lat_90_f10['Kri'])/abs(lat_90_f10['True'])) * 100,
                    (abs(lat_90_f10['True']-lat_90_f10['SVR'])/abs(lat_90_f10['True'])) * 100]).T
error_90_f10.columns = ['ELN','KNN','Kri','SVR']

error_90_f13 = pd.DataFrame(data= [(abs(lat_90_f13['True']-lat_90_f13['ELN'])/abs(lat_90_f13['True'])) * 100 , 
                   (abs(lat_90_f13['True']-lat_90_f13['KNN'])/abs(lat_90_f13['True'])) * 100, 
                   (abs(lat_90_f13['True']-lat_90_f13['Kri'])/abs(lat_90_f13['True'])) * 100,
                    (abs(lat_90_f13['True']-lat_90_f13['SVR'])/abs(lat_90_f13['True'])) * 100]).T
error_90_f13.columns = ['ELN','KNN','Kri','SVR']

error_90_f15 = pd.DataFrame(data= [(abs(lat_90_f15['True']-lat_90_f15['ELN'])/abs(lat_90_f15['True'])) * 100 , 
                   (abs(lat_90_f15['True']-lat_90_f15['KNN'])/abs(lat_90_f15['True'])) * 100, 
                   (abs(lat_90_f15['True']-lat_90_f15['Kri'])/abs(lat_90_f15['True'])) * 100,
                    (abs(lat_90_f15['True']-lat_90_f15['SVR'])/abs(lat_90_f15['True'])) * 100]).T
error_90_f15.columns = ['ELN','KNN','Kri','SVR']

error_90_f16 = pd.DataFrame(data= [(abs(lat_90_f16['True']-lat_90_f16['ELN'])/abs(lat_90_f16['True'])) * 100 , 
                   (abs(lat_90_f16['True']-lat_90_f16['KNN'])/abs(lat_90_f16['True'])) * 100, 
                   (abs(lat_90_f16['True']-lat_90_f16['Kri'])/abs(lat_90_f16['True'])) * 100,
                    (abs(lat_90_f16['True']-lat_90_f16['SVR'])/abs(lat_90_f16['True'])) * 100]).T
error_90_f16.columns = ['ELN','KNN','Kri','SVR']

error_90_f20 = pd.DataFrame(data= [(abs(lat_90_f20['True']-lat_90_f20['ELN'])/abs(lat_90_f20['True'])) * 100 , 
                   (abs(lat_90_f20['True']-lat_90_f20['KNN'])/abs(lat_90_f20['True'])) * 100, 
                   (abs(lat_90_f20['True']-lat_90_f20['Kri'])/abs(lat_90_f20['True'])) * 100,
                    (abs(lat_90_f20['True']-lat_90_f20['SVR'])/abs(lat_90_f20['True'])) * 100]).T
error_90_f20.columns = ['ELN','KNN','Kri','SVR']

error_90_f24 = pd.DataFrame(data= [(abs(lat_90_f24['True']-lat_90_f24['ELN'])/abs(lat_90_f24['True'])) * 100 , 
                   (abs(lat_90_f24['True']-lat_90_f24['KNN'])/abs(lat_90_f24['True'])) * 100, 
                   (abs(lat_90_f24['True']-lat_90_f24['Kri'])/abs(lat_90_f24['True'])) * 100,
                    (abs(lat_90_f24['True']-lat_90_f24['SVR'])/abs(lat_90_f24['True'])) * 100]).T
error_90_f24.columns = ['ELN','KNN','Kri','SVR']

# %%
f2_poly_rmae  = [ error_orig_f2.mean()[0] , error_50_f2.mean()[0], error_70_f2.mean()[0], error_90_f2.mean()[0] ]
f2_knn_rmae  = [ error_orig_f2.mean()[1] , error_50_f2.mean()[1], error_70_f2.mean()[1], error_90_f2.mean()[1] ]
f2_kri_rmae  = [ error_orig_f2.mean()[2] , error_50_f2.mean()[2], error_70_f2.mean()[2], error_90_f2.mean()[2] ]
f2_svr_rmae  = [ error_orig_f2.mean()[3] , error_50_f2.mean()[3], error_70_f2.mean()[3], error_90_f2.mean()[3] ]

f3_poly_rmae  = [ error_orig_f3.mean()[0] , error_50_f3.mean()[0], error_70_f3.mean()[0], error_90_f3.mean()[0] ]
f3_knn_rmae  = [ error_orig_f3.mean()[1] , error_50_f3.mean()[1], error_70_f3.mean()[1], error_90_f3.mean()[1] ]
f3_kri_rmae  = [ error_orig_f3.mean()[2] , error_50_f3.mean()[2], error_70_f3.mean()[2], error_90_f3.mean()[2] ]
f3_svr_rmae  = [ error_orig_f3.mean()[3] , error_50_f3.mean()[3], error_70_f3.mean()[3], error_90_f3.mean()[3] ]

f7_poly_rmae  = [ error_orig_f7.mean()[0] , error_50_f7.mean()[0], error_70_f7.mean()[0], error_90_f7.mean()[0] ]
f7_knn_rmae  = [ error_orig_f7.mean()[1] , error_50_f7.mean()[1], error_70_f7.mean()[1], error_90_f7.mean()[1] ]
f7_kri_rmae  = [ error_orig_f7.mean()[2] , error_50_f7.mean()[2], error_70_f7.mean()[2], error_90_f7.mean()[2] ]
f7_svr_rmae  = [ error_orig_f7.mean()[3] , error_50_f7.mean()[3], error_70_f7.mean()[3], error_90_f7.mean()[3] ]

f9_poly_rmae  = [ error_orig_f9.mean()[0] , error_50_f9.mean()[0], error_70_f9.mean()[0], error_90_f9.mean()[0] ]
f9_knn_rmae  = [ error_orig_f9.mean()[1] , error_50_f9.mean()[1], error_70_f9.mean()[1], error_90_f9.mean()[1] ]
f9_kri_rmae  = [ error_orig_f9.mean()[2] , error_50_f9.mean()[2], error_70_f9.mean()[2], error_90_f9.mean()[2] ]
f9_svr_rmae  = [ error_orig_f9.mean()[3] , error_50_f9.mean()[3], error_70_f9.mean()[3], error_90_f9.mean()[3] ]

f10_poly_rmae  = [ error_orig_f10.mean()[0] , error_50_f10.mean()[0], error_70_f10.mean()[0], error_90_f10.mean()[0] ]
f10_knn_rmae  = [ error_orig_f10.mean()[1] , error_50_f10.mean()[1], error_70_f10.mean()[1], error_90_f10.mean()[1] ]
f10_kri_rmae  = [ error_orig_f10.mean()[2] , error_50_f10.mean()[2], error_70_f10.mean()[2], error_90_f10.mean()[2] ]
f10_svr_rmae  = [ error_orig_f10.mean()[3] , error_50_f10.mean()[3], error_70_f10.mean()[3], error_90_f10.mean()[3] ]

f13_poly_rmae  = [ error_orig_f13.mean()[0] , error_50_f13.mean()[0], error_70_f13.mean()[0], error_90_f13.mean()[0] ]
f13_knn_rmae  = [ error_orig_f13.mean()[1] , error_50_f13.mean()[1], error_70_f13.mean()[1], error_90_f13.mean()[1] ]
f13_kri_rmae  = [ error_orig_f13.mean()[2] , error_50_f13.mean()[2], error_70_f13.mean()[2], error_90_f13.mean()[2] ]
f13_svr_rmae  = [ error_orig_f13.mean()[3] , error_50_f13.mean()[3], error_70_f13.mean()[3], error_90_f13.mean()[3] ]

f15_poly_rmae  = [ error_orig_f15.mean()[0] , error_50_f15.mean()[0], error_70_f15.mean()[0], error_90_f15.mean()[0] ]
f15_knn_rmae  = [ error_orig_f15.mean()[1] , error_50_f15.mean()[1], error_70_f15.mean()[1], error_90_f15.mean()[1] ]
f15_kri_rmae  = [ error_orig_f15.mean()[2] , error_50_f15.mean()[2], error_70_f15.mean()[2], error_90_f15.mean()[2] ]
f15_svr_rmae  = [ error_orig_f15.mean()[3] , error_50_f15.mean()[3], error_70_f15.mean()[3], error_90_f15.mean()[3] ]

f16_poly_rmae  = [ error_orig_f16.mean()[0] , error_50_f16.mean()[0], error_70_f16.mean()[0], error_90_f16.mean()[0] ]
f16_knn_rmae  = [ error_orig_f16.mean()[1] , error_50_f16.mean()[1], error_70_f16.mean()[1], error_90_f16.mean()[1] ]
f16_kri_rmae  = [ error_orig_f16.mean()[2] , error_50_f16.mean()[2], error_70_f16.mean()[2], error_90_f16.mean()[2] ]
f16_svr_rmae  = [ error_orig_f16.mean()[3] , error_50_f16.mean()[3], error_70_f16.mean()[3], error_90_f16.mean()[3] ]

f20_poly_rmae  = [ error_orig_f20.mean()[0] , error_50_f20.mean()[0], error_70_f20.mean()[0], error_90_f20.mean()[0] ]
f20_knn_rmae  = [ error_orig_f20.mean()[1] , error_50_f20.mean()[1], error_70_f20.mean()[1], error_90_f20.mean()[1] ]
f20_kri_rmae  = [ error_orig_f20.mean()[2] , error_50_f20.mean()[2], error_70_f20.mean()[2], error_90_f20.mean()[2] ]
f20_svr_rmae  = [ error_orig_f20.mean()[3] , error_50_f20.mean()[3], error_70_f20.mean()[3], error_90_f20.mean()[3] ]

f24_poly_rmae  = [ error_orig_f24.mean()[0] , error_50_f24.mean()[0],  error_70_f24.mean()[0], error_90_f24.mean()[0] ]
f24_knn_rmae  = [ error_orig_f24.mean()[1] , error_50_f24.mean()[1],  error_70_f24.mean()[1], error_90_f24.mean()[1] ]
f24_kri_rmae  = [ error_orig_f24.mean()[2] , error_50_f24.mean()[2],  error_70_f24.mean()[2], error_90_f24.mean()[2] ]
f24_svr_rmae  = [ error_orig_f24.mean()[3] , error_50_f24.mean()[3], error_70_f24.mean()[3], error_90_f24.mean()[3] ]


f2_poly_std  = [ error_orig_f2.std()[0] , error_50_f2.std()[0], error_70_f2.std()[0], error_90_f2.std()[0] ]
f2_knn_std  = [ error_orig_f2.std()[1] , error_50_f2.std()[1], error_70_f2.std()[1], error_90_f2.std()[1] ]
f2_kri_std  = [ error_orig_f2.std()[2] , error_50_f2.std()[2], error_70_f2.std()[2], error_90_f2.std()[2] ]
f2_svr_std  = [ error_orig_f2.std()[3] , error_50_f2.std()[3], error_70_f2.std()[3], error_90_f2.std()[3] ]

f3_poly_std  = [ error_orig_f3.std()[0] , error_50_f3.std()[0], error_70_f3.std()[0], error_90_f3.std()[0] ]
f3_knn_std  = [ error_orig_f3.std()[1] , error_50_f3.std()[1], error_70_f3.std()[1], error_90_f3.std()[1] ]
f3_kri_std  = [ error_orig_f3.std()[2] , error_50_f3.std()[2], error_70_f3.std()[2], error_90_f3.std()[2] ]
f3_svr_std  = [ error_orig_f3.std()[3] , error_50_f3.std()[3], error_70_f3.std()[3], error_90_f3.std()[3] ]

f7_poly_std  = [ error_orig_f7.std()[0] , error_50_f7.std()[0], error_70_f7.std()[0], error_90_f7.std()[0] ]
f7_knn_std  = [ error_orig_f7.std()[1] , error_50_f7.std()[1], error_70_f7.std()[1], error_90_f7.std()[1] ]
f7_kri_std  = [ error_orig_f7.std()[2] , error_50_f7.std()[2], error_70_f7.std()[2], error_90_f7.std()[2] ]
f7_svr_std  = [ error_orig_f7.std()[3] , error_50_f7.std()[3], error_70_f7.std()[3], error_90_f7.std()[3] ]

f9_poly_std  = [ error_orig_f9.std()[0] , error_50_f9.std()[0], error_70_f9.std()[0], error_90_f9.std()[0] ]
f9_knn_std  = [ error_orig_f9.std()[1] , error_50_f9.std()[1], error_70_f9.std()[1], error_90_f9.std()[1] ]
f9_kri_std  = [ error_orig_f9.std()[2] , error_50_f9.std()[2], error_70_f9.std()[2], error_90_f9.std()[2] ]
f9_svr_std  = [ error_orig_f9.std()[3] , error_50_f9.std()[3], error_70_f9.std()[3], error_90_f9.std()[3] ]

f10_poly_std  = [ error_orig_f10.std()[0] , error_50_f10.std()[0], error_70_f10.std()[0], error_90_f10.std()[0] ]
f10_knn_std  = [ error_orig_f10.std()[1] , error_50_f10.std()[1], error_70_f10.std()[1], error_90_f10.std()[1] ]
f10_kri_std  = [ error_orig_f10.std()[2] , error_50_f10.std()[2], error_70_f10.std()[2], error_90_f10.std()[2] ]
f10_svr_std  = [ error_orig_f10.std()[3] , error_50_f10.std()[3], error_70_f10.std()[3], error_90_f10.std()[3] ]

f13_poly_std  = [ error_orig_f13.std()[0] , error_50_f13.std()[0], error_70_f13.std()[0], error_90_f13.std()[0] ]
f13_knn_std  = [ error_orig_f13.std()[1] , error_50_f13.std()[1], error_70_f13.std()[1], error_90_f13.std()[1] ]
f13_kri_std  = [ error_orig_f13.std()[2] , error_50_f13.std()[2], error_70_f13.std()[2], error_90_f13.std()[2] ]
f13_svr_std  = [ error_orig_f13.std()[3] , error_50_f13.std()[3], error_70_f13.std()[3], error_90_f13.std()[3] ]

f15_poly_std  = [ error_orig_f15.std()[0] , error_50_f15.std()[0], error_70_f15.std()[0], error_90_f15.std()[0] ]
f15_knn_std  = [ error_orig_f15.std()[1] , error_50_f15.std()[1], error_70_f15.std()[1], error_90_f15.std()[1] ]
f15_kri_std  = [ error_orig_f15.std()[2] , error_50_f15.std()[2], error_70_f15.std()[2], error_90_f15.std()[2] ]
f15_svr_std  = [ error_orig_f15.std()[3] , error_50_f15.std()[3], error_70_f15.std()[3], error_90_f15.std()[3] ]

f16_poly_std  = [ error_orig_f16.std()[0] , error_50_f16.std()[0], error_70_f16.std()[0], error_90_f16.std()[0] ]
f16_knn_std  = [ error_orig_f16.std()[1] , error_50_f16.std()[1], error_70_f16.std()[1], error_90_f16.std()[1] ]
f16_kri_std  = [ error_orig_f16.std()[2] , error_50_f16.std()[2], error_70_f16.std()[2], error_90_f16.std()[2] ]
f16_svr_std  = [ error_orig_f16.std()[3] , error_50_f16.std()[3], error_70_f16.std()[3], error_90_f16.std()[3] ]

f20_poly_std  = [ error_orig_f20.std()[0] , error_50_f20.std()[0], error_70_f20.std()[0], error_90_f20.std()[0] ]
f20_knn_std  = [ error_orig_f20.std()[1] , error_50_f20.std()[1], error_70_f20.std()[1], error_90_f20.std()[1] ]
f20_kri_std  = [ error_orig_f20.std()[2] , error_50_f20.std()[2], error_70_f20.std()[2], error_90_f20.std()[2] ]
f20_svr_std  = [ error_orig_f20.std()[3] , error_50_f20.std()[3], error_70_f20.std()[3], error_90_f20.std()[3] ]

f24_poly_std  = [ error_orig_f24.std()[0] , error_50_f24.std()[0],  error_70_f24.std()[0], error_90_f24.std()[0] ]
f24_knn_std  = [ error_orig_f24.std()[1] , error_50_f24.std()[1],  error_70_f24.std()[1], error_90_f24.std()[1] ]
f24_kri_std  = [ error_orig_f24.std()[2] , error_50_f24.std()[2],  error_70_f24.std()[2], error_90_f24.std()[2] ]
f24_svr_std  = [ error_orig_f24.std()[3] , error_50_f24.std()[3], error_70_f24.std()[3], error_90_f24.std()[3] ]

f2_poly_time  = [ 8.81, 2 , 0.630 , 0.615]
#f2_knn_time  = [ 0.00821 , 0.008 , 0.01 , 0.00735]
f2_kri_time  = [ 311, 240 , 157 , 116]
f2_svr_time  = [ 4.4 , 2 , 1.3 , 0.718]

f3_poly_time  = [ 6.7 , 2.2 , 0.729 , 0.083 ]
#f3_knn_time  = [ 0.0185 , 0.008 , 0.0079 , 0.0083 ]
f3_kri_time  = [ 297 , 231 , 151 , 104 ]
f3_svr_time  = [ 4.4 , 2 , 1.3 , 0.762 ]

f7_poly_time  = [ 73 , 2.1 , 0.698, 0.090 ]
#f7_knn_time  = [ 0.0201 , 0.0082 , 0.0078 , 0.0083 ]
f7_kri_time  = [ 291 , 234 , 160 ,  126]
f7_svr_time  = [ 4.4 , 5.3 , 2.96 , 1 ]

f9_poly_time  = [ 139 , 2 , 0.660 , 2.5 ]
#f9_knn_time  = [ 0.0254 , 0.0089 , 0.0077 , 0.0091 ]
f9_kri_time  = [ 55 , 37 , 33.3 , 25 ]
f9_svr_time  = [ 10 , 2 , 1.3 , 0.168 ]

f10_poly_time  = [ 125 , 1.9 , 0.642 , 1.2 ]
#f10_knn_time  = [ 0.0189 , 0.0079 , 0.0088 , 0.0085 ]
f10_kri_time  = [ 319 , 266 , 190 , 134 ]
f10_svr_time  = [ 10 , 2.3 , 1.3 ,0.809 ]

f13_poly_time  = [  62, 1.6 , 0.720 , 0.105]
#f13_knn_time  = [ 0.0208 , 0.00775 , 0.0076 , 0.008 ]
f13_kri_time  = [ 273 , 271 , 197 , 143 ]
f13_svr_time  = [ 4.4 , 1.9 , 2.1 , 0.621 ]

f15_poly_time  = [ 26 , 2 , 0.717 , 0.1 ]
#f15_knn_time  = [ 0.0189 , 0.008 , 0.0076 , 0.0088]
f15_kri_time  = [ 312 , 248 , 154 , 95  ]
f15_svr_time  = [ 10 , 2 , 1.4 , 0.624 ]

f16_poly_time  = [ 13 , 103 , 0.575 , 0.079 ]
#f16_knn_time  = [ 0.0246 , 0.022 , 0.013 , 0.019 ]
f16_kri_time  = [ 312 , 260 , 125 , 102 ]
f16_svr_time  = [ 10 , 2 , 1.3 , 0.621 ]

f20_poly_time  = [ 10 , 2.1 , 0.653 , 0.088 ]
#f20_knn_time  = [ 0.0182 , 0.008 , 0.0071 , 0.0086 ]
f20_kri_time  = [ 273 , 233 , 157, 152 ]
f20_svr_time  = [ 4.4 , 2 , 1.3 , 0.719 ]

f24_poly_time  = [57 , 2.2 , 0.714 , 0.101 ]
#f24_knn_time  = [ 0.0632 , 0.027 , 0.0074 , 0.0085 ]
f24_kri_time  = [ 352 , 230 , 158 , 81 ]
f24_svr_time  = [9, 1.9 , 1.3 , 0.623 ]

# %%
cols = ['Noise Level : 5 %','Noise Level : 10 %','Noise Level : 20 %']
rows = ['F(2,3,7,9,10)','F(13,15,16,20,24)']

f, axarr = plt.subplots(2, 5,figsize=(15,6))


line = []
line.append(axarr[0,0].errorbar(f2_poly_rmae , f2_poly_time  , marker='v', 
                     color='r',label='ELN', fillstyle='none',markersize=8)[0])
line.append(axarr[0,0].errorbar(f2_kri_rmae, f2_kri_time,  marker='s', 
                     color='b',label='Kriging',fillstyle='none',markersize=8)[0])
line.append(axarr[0,0].errorbar(f2_svr_rmae , f2_svr_time,   marker='*', 
                     color='g',label='SVR',fillstyle='none',markersize=8)[0])

axarr[0,0].set_yscale('log',basey=2)
axarr[0,0].set_xscale('log',basex=2)
axarr[0,0].set_ylabel('Time (Seconds)',size=12)
axarr[0,0].grid(which='major')
axarr[0,0].set_title('F2')
axarr[0,0].tick_params(labelsize=12)

axarr[0,1].errorbar( f3_poly_rmae, f3_poly_time , marker='v' ,  color='r', fillstyle='none',markersize=8)
axarr[0,1].errorbar(f3_poly_rmae , f3_kri_time,  marker='s' , color='b', fillstyle='none',markersize=8)
axarr[0,1].errorbar(f3_poly_rmae , f3_svr_time, marker='*' , color='g', fillstyle='none',markersize=8)

axarr[0,1].set_yscale('log',basey=2)
axarr[0,1].set_xscale('log',basex=2)
axarr[0,1].grid(which='major')
axarr[0,1].set_title('F3')
axarr[0,1].tick_params(labelsize=12)

axarr[0,2].errorbar(f7_poly_rmae , f7_poly_time , marker='v' ,  color='r', fillstyle='none',markersize=8)
axarr[0,2].errorbar(f7_poly_rmae , f7_kri_time,  marker='s' , color='b', fillstyle='none',markersize=8)
axarr[0,2].errorbar(f7_poly_rmae , f7_svr_time,  marker='*' , color='g', fillstyle='none',markersize=8)

axarr[0,2].set_yscale('log',basey=2)
axarr[0,2].set_xscale('log',basex=2)
axarr[0,2].grid(which='major')
axarr[0,2].set_title('F7')
axarr[0,2].tick_params(labelsize=12)

axarr[0,3].errorbar(f9_poly_rmae , f9_poly_time, marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[0,3].errorbar(f9_poly_rmae , f9_kri_time,  marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[0,3].errorbar(f9_poly_rmae, f9_svr_time,   marker='*' , color='g', fillstyle='none',markersize=8)


axarr[0,3].set_yscale('log',basey=2)
axarr[0,3].grid(which='major')
axarr[0,3].set_title('F9')
axarr[0,3].set_xscale('log',basex=2)
axarr[0,3].tick_params(labelsize=12)


axarr[0,4].errorbar(f10_poly_rmae, f10_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[0,4].errorbar(f10_poly_rmae , f10_kri_time,  marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[0,4].errorbar(f10_poly_rmae, f10_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[0,4].set_yscale('log',basey=2)
axarr[0,4].set_xscale('log',basex=2)
axarr[0,4].grid(which='major')
axarr[0,4].set_title('F10')
axarr[0,4].tick_params(labelsize=12)

axarr[1,0].errorbar(f13_poly_rmae, f13_poly_time,   marker='v' ,  color='r', fillstyle='none',markersize=8)
axarr[1,0].errorbar(f13_poly_rmae, f13_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,0].errorbar(f13_poly_rmae, f13_svr_time, marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,0].set_xlabel('RMAE (%)',size=12)
axarr[1,0].set_yscale('log',basey=2)
axarr[1,0].set_xscale('log',basex=2)
axarr[1,0].set_ylabel('Time (Seconds)',size=12)
axarr[1,0].grid(which='major')
axarr[1,0].set_title('F13')
axarr[1,0].tick_params(labelsize=12)

axarr[1,1].errorbar(f15_poly_rmae, f15_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,1].errorbar(f15_poly_rmae, f15_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,1].errorbar(f15_poly_rmae, f15_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,1].set_xlabel('RMAE (%)',size=12)
axarr[1,1].set_yscale('log',basey=2)
axarr[1,1].set_xscale('log',basex=2)
axarr[1,1].grid(which='major')
axarr[1,1].set_title('F15')
axarr[1,1].tick_params(labelsize=12)

axarr[1,2].errorbar(f16_poly_rmae, f16_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,2].errorbar(f16_poly_rmae, f16_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,2].errorbar(f16_poly_rmae,f16_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)

axarr[1,2].set_xlabel('RMAE (%)',size=12)
axarr[1,2].set_yscale('log',basey=2)
axarr[1,2].set_xscale('log',basex=2)
axarr[1,2].grid(which='major')
axarr[1,2].set_title('F16')
axarr[1,2].tick_params(labelsize=12)

axarr[1,3].errorbar(f20_poly_rmae, f20_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,3].errorbar(f20_poly_rmae, f20_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,3].errorbar(f20_poly_rmae, f20_svr_time,   marker='*' , color='g', fillstyle='none',markersize=8)

axarr[1,3].set_xlabel('RMAE (%)',size=12)
axarr[1,3].set_xscale('log',basex=2)
axarr[1,3].set_yscale('log',basey=2)
axarr[1,3].grid(which='major')
axarr[1,3].set_title('F20')
axarr[1,3].tick_params(labelsize=12)

axarr[1,4].errorbar(f24_poly_rmae, f24_poly_time,   marker='v' ,   color='r', fillstyle='none',markersize=8)
axarr[1,4].errorbar(f24_poly_rmae, f24_kri_time,   marker='s' ,  color='b', fillstyle='none',markersize=8)
axarr[1,4].errorbar(f24_poly_rmae, f24_svr_time,   marker='*' ,  color='g', fillstyle='none',markersize=8)
axarr[1,4].set_xlabel('RMAE (%)',size=12)
axarr[1,4].set_yscale('log',basey=2)
axarr[1,4].set_xscale('log',basex=2)
axarr[1,4].grid(which='major')
axarr[1,4].set_title('F24')
axarr[1,4].tick_params(labelsize=12)

pad = 10

f.tight_layout() 
#f.legend(line, ['ELN', 'Kriging', 'SVR'], loc='upper left', fontsize=12 , ncol=3 , bbox_to_anchor=(0.37, 1.07),fancybox=True  )
plt.show()
f.savefig("200 D.eps",bbox_inches='tight')
